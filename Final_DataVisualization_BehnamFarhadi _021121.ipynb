# %% [markdown]
# # Final Project
# ## COMP-6934-001 (Intro to Data Visualization)

# %% [markdown]
# ## Behnam Farhadi
# ### 201994394  /  bfarhadi@mun.ca

# %% [markdown]
# ### 1.	Average of Customer Satisfaction for each Team
#
# ####  CSAT is the best single KPI for measuring the quality of the service provided and tracking how the team is performing against this goal. All other important Customer Support metrics (like First Response Time (FRT) and Average Resolution Time (ART)) ultimately feed into a team’s CSAT score.

# %% [markdown]
# ### Since this is a qualitative value, I assigned the following values for numbers 1 to 5.
# [ 1. Very unsatisfied, 2. Unsatisfied, 3. Neutral, 4. Satisfied, 5. Very satisfied].
# #### CSAT   = (Number of positive responses / Total number of responses) * 100

# %% [markdown]
# #### I have calculated this feature separately for each team and displayed it interactively with the pie chart plot.

# %%
pip install plotly
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from ipywidgets import interact, interact_manual
import ipywidgets as widgets
import plotly.express as px

# %%
df=pd.read_csv('tickets.csv', parse_dates=['action_date','view_date', 'creation_date' ])
df.count()
# Out:
# ticket_type                  31520
# creation_date                31520
# view_date                    31520
# action_date                  31520
# customer_satisfaction        31520
# customer_problem_resolved    31520
# user_actioned                31520
# user_team                    31520
# dtype: int64

# %%
df.user_team.unique()
# Out:
# array(['orange', 'blue', 'green', 'red'], dtype=object)

# %%
#All numbers of tickets belong to Orange group
dfo=df[(df['user_team']=='orange')]

# %%
#Satisfication percent with number 1 for orange team
dfo1=df[(df['customer_problem_resolved']==True ) & (df['user_team']=='orange' ) & (df['customer_satisfaction']==1 )]
po1 = (569/5419)*100

# %%
#Satisfication percent with number 2 for orange team
dfo2=df[(df['customer_problem_resolved']==True ) & (df['user_team']=='orange' ) & (df['customer_satisfaction']==2 )]
po2 = (341/5419)*100

# %%
#Satisfication percent with number 3 for orange team
dfo3=df[(df['customer_problem_resolved']==True ) & (df['user_team']=='orange' ) & (df['customer_satisfaction']==3 )]
po3 = (530/5419)*100

# %%
#Satisfication percent with number 4 for orange team
dfo4=df[(df['customer_problem_resolved']==True ) & (df['user_team']=='orange' ) & (df['customer_satisfaction']==4 )]
po4 = (249/5419)*100

# %%
#Satisfication percent with number 5 for orange team
dfo5=df[(df['customer_problem_resolved']==True ) & (df['user_team']=='orange' ) & (df['customer_satisfaction']==5 )]
po5 = (34/5419)*100

# %%
CSAT = (1723/5419)*100

# %%
#All numbers of tickets belong to blue group
dfb=df[(df['user_team']=='blue')]

# %%
#Satisfication percent with number 1 for blue team
dfb1=df[(df['customer_problem_resolved']==True ) & (df['user_team']=='blue' ) & (df['customer_satisfaction']==1 )]
pb1 = (432/6828)*100

# %%
#Satisfication percent with number 2 for blue team
dfb2=df[(df['customer_problem_resolved']==True ) & (df['user_team']=='blue' ) & (df['customer_satisfaction']==2 )]
pb2 = (401/6828)*100

# %%
#Satisfication percent with number 3 for blue team
dfb3=df[(df['customer_problem_resolved']==True ) & (df['user_team']=='blue' ) & (df['customer_satisfaction']==3 )]
pb3 = (724/6828)*100

# %%
#Satisfication percent with number 4 for blue team
dfb4=df[(df['customer_problem_resolved']==True ) & (df['user_team']=='blue' ) & (df['customer_satisfaction']==4 )]
pb4 = (632/6828)*100

# %%
#Satisfication percent with number 5 for blue team
dfb5=df[(df['customer_problem_resolved']==True ) & (df['user_team']=='blue' ) & (df['customer_satisfaction']==5 )]
pb5 = (832/6828)*100

# %%
#All numbers of tickets belong to green group
dfg=df[(df['user_team']=='green')]

# %%
#Satisfication percent with number 1 for green team
dfg1=df[(df['customer_problem_resolved']==True ) & (df['user_team']=='green' ) & (df['customer_satisfaction']==1 )]
pg1 = (797/12309)*100

# %%
#Satisfication percent with number 2 for green team
dfg2=df[(df['customer_problem_resolved']==True ) & (df['user_team']=='green' ) & (df['customer_satisfaction']==2 )]
pg2 = (724/12309)*100

# %%
#Satisfication percent with number 3 for green team
dfg3=df[(df['customer_problem_resolved']==True ) & (df['user_team']=='green' ) & (df['customer_satisfaction']==3 )]
pg3 = (1254/12309)*100

# %%
#Satisfication percent with number 4 for green team
dfg4=df[(df['customer_problem_resolved']==True ) & (df['user_team']=='green' ) & (df['customer_satisfaction']==4 )]
pg4 = (1353/12309)*100

# %%
#Satisfication percent with number 5 for green team
dfg5=df[(df['customer_problem_resolved']==True ) & (df['user_team']=='green' ) & (df['customer_satisfaction']==5 )]
pg5 = (1572/12309)*100

# %%
#All numbers of tickets belong to red group
dfr=df[(df['user_team']=='red')]

# %%
#Satisfication percent with number 1 for red team
dfr1=df[(df['customer_problem_resolved']==True ) & (df['user_team']=='red' ) & (df['customer_satisfaction']==1 )]
pr1 = (415/6964)*100

# %%
#Satisfication percent with number 2 for red team
dfr2=df[(df['customer_problem_resolved']==True ) & (df['user_team']=='red' ) & (df['customer_satisfaction']==2 )]
pr2 = (416/6964)*100

# %%
#Satisfication percent with number 3 for red team
dfr3=df[(df['customer_problem_resolved']==True ) & (df['user_team']=='red' ) & (df['customer_satisfaction']==3 )]
pr3 = (717/6964)*100

# %%
#Satisfication percent with number 4 for red team
dfr4=df[(df['customer_problem_resolved']==True ) & (df['user_team']=='red' ) & (df['customer_satisfaction']==4 )]
pr4 = (828/6964)*100

# %%
#Satisfication percent with number 5 for red team
dfr5=df[(df['customer_problem_resolved']==True ) & (df['user_team']=='red' ) & (df['customer_satisfaction']==5 )]
pr5 = (930/6964)*100

# %%
#Total CSAT for Red Team
dfr6=df[(df['customer_problem_resolved']==True ) & (df['user_team']=='red' ) ]
dfr6.count()
dfr6 = 3306/31520

# %%
#Total CSAT for Blue Team
dfr7=df[(df['customer_problem_resolved']==True ) & (df['user_team']=='blue' ) ]
dfr7.count()
dfr7 = 3021/31520

# %%
#Total CSAT for Green Team
dfr8=df[(df['customer_problem_resolved']==True ) & (df['user_team']=='green' ) ]
dfr8.count()
dfr8 = 5700/31520

# %%
#Total CSAT for Orange Team
dfr9=df[(df['customer_problem_resolved']==True ) & (df['user_team']=='orange' ) ]
dfr9.count()
dfr9 = 1723/31520

# %%
#Percent of unsolved Tickets
dfr10=df[(df['customer_problem_resolved']==False ) ]
dfr10.count()
dfr10 = 17770/31520

# %%
@interact(Team=widgets.Dropdown(options=['orange', 'blue', 'green', 'red']), Total_Ticket_Type=False , Overall_performance=False)

def f(Team,Total_Ticket_Type,Overall_performance):
    fig, ax = plt.subplots(figsize=(10,7))
    # at below I tried to show and use different types of color palette
    colorsr = sns.light_palette(color='#b60c26',n_colors=6,reverse=False,input='hsl')
    colorsg =sns.color_palette("ch:2,r=.2,l=.6")
    colorso = sns.color_palette('Oranges')
    colorsb = sns.color_palette("ch:s=.25,rot=-.25")
    colorst = sns.cubehelix_palette(start=2.8, rot=.1)
    ax.set_title("Customer Satisfaction percent for"+ " " + str(Team)+ " "+ "Team",y=1.2, fontsize = 22 )

#     colors = ( "orange", "cyan", "brown",
#           "grey", "indigo", "beige")
# Orange Team User Satisfication
    #fig = plt.figure()
    #ax = fig.add_subplot(111)
    #fig = plt.figure(figsize =(10, 7))
    if Team=='orange':
        # Creating dataset
        CSAT = ['Very_unsatisfied', 'Unsatisfied', 'Neutral', 'Satisfied', 'Very_satisfied']
        # colors = sns.color_palette('bright')[0:5]  
        datao = [10.50, 6.29, 9.78, 4.59, 0.62]
        # Creating explode data
        explode = (0.1, 0.0, 0.0, 0.0, 0.2) # Creating plot
#         fig = plt.figure(figsize =(10, 7))
        ax = plt.pie(datao, labels = CSAT ,explode=explode, colors=colorso, autopct='%1.1f%%',shadow=True, startangle=90)

        # show plot
        plt.show()

# Blue Team User Satisfication 
    if Team=='blue':
        # Creating dataset
        CSAT = ['Very_unsatisfied', 'Unsatisfied', 'Neutral', 'Satisfied', 'Very_satisfied']
        # colors = sns.color_palette('bright')[0:5]  
        datab = [6.32, 5.87, 10.60, 9.25, 12.18]
        # Creating explode data
        explode = (0.1, 0.0, 0.0, 0.0, 0.2) # Creating plot
#         fig = plt.figure(figsize =(10, 7))
        ax =plt.pie(datab, labels = CSAT ,explode=explode, colors=colorsb, autopct='%1.1f%%',shadow=True, startangle=90)

        # show plot
        plt.show()
        
# Green Team User Satisfication 
    if Team=='green':
        # Creating dataset
        CSAT = ['Very_unsatisfied', 'Unsatisfied', 'Neutral', 'Satisfied', 'Very_satisfied']
        # colors = sns.color_palette('bright')[0:5]  
        datab = [6.47, 5.88, 10.18, 10.99, 12.77]
        # Creating explode data
        explode = (0.1, 0.0, 0.0, 0.0, 0.2) 
#         fig = plt.figure(figsize =(10, 7))
        ax =plt.pie(datab, labels = CSAT ,explode=explode,colors=colorsg,  autopct='%1.1f%%',shadow=True, startangle=90)

        # show plot
        plt.show()
        
# Red Team User Satisfication 
    if Team=='red':
        # Creating dataset
        CSAT = ['Very_unsatisfied', 'Unsatisfied', 'Neutral', 'Satisfied', 'Very_satisfied']
        # colors = sns.color_palette('bright')[0:5]  
        datab = [5.95, 5.97, 10.29, 11.88, 13.35]
        # Creating explode data
        explode = (0.1, 0.0, 0.0, 0.0, 0.2) # Creating plot
#         fig = plt.figure(figsize =(10, 7))
        ax =plt.pie(datab, labels = CSAT ,explode=explode, colors=colorsr, autopct='%1.1f%%',shadow=True, startangle=90)

       
        # show plot
        plt.show()
        
    if(Total_Ticket_Type==True):
        colors = sns.color_palette("ch:s=.25,rot=-.25")
        # Creating dataset
        CSAT = ['webform', 'live chat', 'email']
        # colors = sns.color_palette('bright')[0:5]  
        datao = [45.01, 9.40, 45.57]
        # Creating explode data
        explode = (0.1, 0.2, 0.0) # Creating plot
        fig = plt.figure(figsize =(10, 7))
        plt.title("All received tickets separately by email, web_form and live_chat", fontsize = 22)
        ax = plt.pie(datao, labels = CSAT ,explode=explode, colors=colors, autopct='%1.1f%%',shadow=True, startangle=90)
        fig = plt.figure(figsize =(10, 7))
        # show plot
        plt.show()
        
 #Overall_performance
    if(Overall_performance==True):
        colors = sns.color_palette("ch:s=.25,rot=-.25")
        # Creating dataset
        CSAT = ['red', 'blue', 'green','orange', 'Unresolved_problems']
        # colors = sns.color_palette('bright')[0:5]  
        datao = [0.10, 0.09, 0.18, 0.05, 0.56]
        # Creating explode data
        explode = (0.0, 0.0, 0.1, 0.0,0.2) # Creating plot
        fig = plt.figure(figsize =(10, 7))
        plt.title("Percent of Resolved problems seperately by each team and Unresolved Problems ", fontsize = 22)
        ax =plt.pie(datao, labels = CSAT ,explode=explode, colors=colorst, autopct='%1.1f%%',shadow=True, startangle=90)
        
        # show plot
        plt.show()
# Out:
# interactive(children=(Dropdown(description='Team', options=('orange', 'blue', 'green', 'red'), value='orange')…

# %% [markdown]
# # 2.Numbers of Solved Tickets by each person, team and overall (Circlify)
# ### For this first plot, I have extracted the members of each team. Then I calculated how many tickets each person successfully solved. And then the total number of tickets solved by each team and finally the total number of tickets solved by 4 teams is specified. According to this chart, it is possible to find out which user and which team have solved the most tickets.

# %%
pip install circlify
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import circlify

# %%
#Extract red team members
red=df[(df['user_team']=='red' )]
red.user_actioned.unique()
# Out:
# array(['3b71e1', '8f017e', '533204', '9009ab'], dtype=object)

# %%
#Extract orange team members
orange=df[(df['user_team']=='orange' )]
orange.user_actioned.unique()
# Out:
# array(['291950', '49706a', '93d960', '7544bc'], dtype=object)

# %%
#Extract green team members
green=df[(df['user_team']=='green' )]
green.user_actioned.unique()
# Out:
# array(['2275ef', '48d2a0', '7dc1b8', '350e29', 'ed57', '4d6f54', '1f34a0'],
#       dtype=object)

# %%
#Extract blue team members
blue=df[(df['user_team']=='blue' )]
blue.user_actioned.unique()
# Out:
# array(['5f3afd', '38f7e2', '481f09', '5a00c4', '7f3d9f'], dtype=object)

# %%
#red array(['3b71e1', '8f017e', '533204', '9009ab'], dtype=object)
#orange array(['291950', '49706a', '93d960', '7544bc'], dtype=object)
#green arrayarray(['2275ef', '48d2a0', '7dc1b8', '350e29', 'ed57', '4d6f54', '1f34a0'], dtype=object)
#blue array(['5f3afd', '38f7e2', '481f09', '5a00c4', '7f3d9f'], dtype=object)

# %%
#Calculate numbers of ticket solved by members
# Red team members
r3b71e1=df[(df['customer_problem_resolved']==True ) & (df['user_actioned']=='3b71e1' )]
r8f017e=df[(df['customer_problem_resolved']==True ) & (df['user_actioned']=='8f017e' )]
r533204=df[(df['customer_problem_resolved']==True ) & (df['user_actioned']=='533204' )]
r9009ab=df[(df['customer_problem_resolved']==True ) & (df['user_actioned']=='9009ab' )]

# orange team members
o291950=df[(df['customer_problem_resolved']==True ) & (df['user_actioned']=='291950' )]
o49706a=df[(df['customer_problem_resolved']==True ) & (df['user_actioned']=='49706a' )]
o93d960=df[(df['customer_problem_resolved']==True ) & (df['user_actioned']=='93d960' )]
o7544bc=df[(df['customer_problem_resolved']==True ) & (df['user_actioned']=='7544bc' )]

# Green team members
g2275ef=df[(df['customer_problem_resolved']==True ) & (df['user_actioned']=='2275ef' )]
g48d2a0=df[(df['customer_problem_resolved']==True ) & (df['user_actioned']=='48d2a0' )]
g7dc1b8=df[(df['customer_problem_resolved']==True ) & (df['user_actioned']=='7dc1b8' )]
g350e29=df[(df['customer_problem_resolved']==True ) & (df['user_actioned']=='350e29' )]
ged57=df[(df['customer_problem_resolved']==True ) & (df['user_actioned']=='ed57' )]
g4d6f54=df[(df['customer_problem_resolved']==True ) & (df['user_actioned']=='4d6f54' )]
g1f34a0=df[(df['customer_problem_resolved']==True ) & (df['user_actioned']=='1f34a0' )]


# Blue team members
b5f3afd=df[(df['customer_problem_resolved']==True ) & (df['user_actioned']=='5f3afd' )]
b38f7e2=df[(df['customer_problem_resolved']==True ) & (df['user_actioned']=='38f7e2' )]
b481f09=df[(df['customer_problem_resolved']==True ) & (df['user_actioned']=='481f09' )]
b5a00c4=df[(df['customer_problem_resolved']==True ) & (df['user_actioned']=='5a00c4' )]
b7f3d9f=df[(df['customer_problem_resolved']==True ) & (df['user_actioned']=='7f3d9f' )]

# %%
red=df[df.user_team =='red'].reset_index()
blue=df[df.user_team =='blue'].reset_index()
green=df[df.user_team =='green'].reset_index()
orange=df[df.user_team =='orange'].reset_index()

# %%
data = [{'id' : "red", 'datum': 3306,
                   'children' : [
                     {'id' : "3b71e1", 'datum' : 731},
                     {'id' : "8f017e", 'datum' : 725},
                     {'id' : "533204", 'datum' : 806},
                     {'id' : "9009ab", 'datum' : 1044},
                   ]},
              {'id' : "orange", 'datum' : 1723, 
                   'children' : [
                     {'id' : "291950", 'datum' : 530},
                     {'id' : "49706a", 'datum' : 383},
                     {'id' : "93d960", 'datum' : 445},
                     {'id' : "7544bc", 'datum' : 365},
                   ]},
              {'id' : "blue", 'datum' : 3021, 
                   'children' : [
                     {'id' : "5f3afd", 'datum' : 726},
                     {'id' : "38f7e2", 'datum' : 402},
                     {'id' : "481f09", 'datum' : 492},
                     {'id' : "5a00c4", 'datum' : 842},
                     {'id' : "7f3d9f", 'datum' : 559},

                   ]},
        
              {'id' : "green", 'datum' : 5700,  
                   'children' : [
                     {'id' : "2275ef", 'datum' : 898},
                     {'id' : "48d2a0", 'datum' : 1287},
                     {'id' : "7dc1b8", 'datum' : 717},
                     {'id' : "350e29", 'datum' : 639},
                     {'id' : "ed57", 'datum' : 608},
                     {'id' : "4d6f54", 'datum' : 685},
                     {'id' : "1f34a0", 'datum' : 866},
                   ]},             
    ]

# %%
# Compute circle positions thanks to the circlify() function
circles = circlify.circlify(
    data, 
    show_enclosure=False, 
    target_enclosure=circlify.Circle(x=0, y=0, r=1)
)

# Create just a figure and only one subplot
fig, ax = plt.subplots(figsize=(14,14))

# Title
ax.set_title('Amount of Solved Tickets by each person, team and overall', fontsize = 22)

# Remove axes
ax.axis('off')

# Find axis boundaries
lim = max(
    max(
        abs(circle.x) + circle.r,
        abs(circle.y) + circle.r,
    )
    for circle in circles
)
plt.xlim(-lim, lim)
plt.ylim(-lim, lim)

# Print circle the highest level (continents):
for circle in circles:
    if circle.level != 1:
      continue
    x, y, r = circle
    if circle.ex["id"]== 'green':
      ax.add_patch( plt.Circle((x, y), r, alpha=1, color="#75C888",fill=False, linewidth=2))
    if circle.ex["id"]== 'blue':
      ax.add_patch( plt.Circle((x, y), r, alpha=1, color="#3745db",fill=False, linewidth=2))
    if circle.ex["id"]== 'red':
      ax.add_patch( plt.Circle((x, y), r, alpha=1, color="#d61d09",fill=False, linewidth=2))
    if circle.ex["id"]== 'orange':
      ax.add_patch( plt.Circle((x, y), r, alpha=1, color="#f58105",fill=False, linewidth=2))

red_label = red['user_actioned'].to_list()
blue_label = blue['user_actioned'].to_list()
green_label = green['user_actioned'].to_list()
orange_label = orange['user_actioned'].to_list()

# Print circle and labels for the highest level:
for circle in circles:
    if circle.level != 2:
      continue
    x, y, r = circle
    label = circle.ex["id"]

    if label in red_label:
      ax.add_patch( plt.Circle((x, y), r, alpha=0.5, linewidth=2, color="#d61d09"))
      plt.annotate(label, (x,y ), ha='center', color="black")

    if label in blue_label:
      ax.add_patch( plt.Circle((x, y), r, alpha=0.5, linewidth=2, color="#3745db"))
      plt.annotate(label, (x,y ), ha='center', color="black")  

    if label in green_label:
      ax.add_patch( plt.Circle((x, y), r, alpha=0.5, linewidth=2, color="#75C888"))
      plt.annotate(label, (x,y ), ha='center', color="black")    

    if label in orange_label:
      ax.add_patch( plt.Circle((x, y), r, alpha=0.5, linewidth=2, color="#f58105"))
      plt.annotate(label, (x,y ), ha='center', color="black")

# %% [markdown]
# ## 3- Ticket Volume (number of tickets per each Weeks, Line chart)
# ### One of the simplest but most powerful metrics is a count of every single interaction the team has had with the customers over a given period. Tracking this over time can give us a 360 degree view of support trends. For this part, I want to calculate the number of tickets that sent to each team, regardless of the type of ticket.

# %%
df2=df
df2['Difference'] = df2['action_date'].sub(df2['view_date'], axis=0) 
df2
# Out:
#       ticket_type       creation_date                  view_date  \
# 0       live_chat 2021-07-02 08:36:00 2021-07-02 08:36:00.000000
# 1        web_form 2021-07-02 02:37:00 2021-07-02 08:51:00.000000
# 2        web_form 2021-07-02 02:50:00 2021-07-02 09:15:00.000000
# 3        web_form 2021-07-02 02:01:00 2021-07-02 09:44:00.000000
# 4        web_form 2021-07-02 02:41:00 2021-07-02 10:14:00.000000
# ...           ...                 ...                        ...
# 31515       email 2021-09-29 02:56:00 2021-09-29 14:56:44.829513
# 31516       email 2021-09-28 17:20:00 2021-09-29 15:19:44.829513
# 31517    web_form 2021-09-28 23:08:00 2021-09-29 15:57:44.829513
# 31518    web_form 2021-09-29 13:31:00 2021-09-29 16:14:44.829513
# 31519    web_form 2021-09-28 23:13:00 2021-09-29 16:37:44.829513
#
#                      action_date  customer_satisfaction  \
# 0     2021-07-02 08:50:00.000000                      1
# 1     2021-07-02 09:12:00.000000                      1
# ...

# %%
# generating all dates in given range
# with increment by days
allDates = pd.date_range('2021-07-02', '2021-09-29', freq ='W')

# converting dates to series
series = allDates.to_series()
  
series.dt.week
# Out:
# <ipython-input-256-b9976d9d2683>:8: FutureWarning: Series.dt.weekofyear and Series.dt.week have been deprecated.  Please use Series.dt.isocalendar().week instead.
#   series.dt.week
# 2021-07-04    26
# 2021-07-11    27
# 2021-07-18    28
# 2021-07-25    29
# 2021-08-01    30
# 2021-08-08    31
# 2021-08-15    32
# 2021-08-22    33
# 2021-08-29    34
# 2021-09-05    35
# 2021-09-12    36
# 2021-09-19    37
# 2021-09-26    38
# Freq: W-SUN, dtype: int64

# %%
df4=df
df4
# Out:
#       ticket_type       creation_date                  view_date  \
# 0       live_chat 2021-07-02 08:36:00 2021-07-02 08:36:00.000000
# 1        web_form 2021-07-02 02:37:00 2021-07-02 08:51:00.000000
# 2        web_form 2021-07-02 02:50:00 2021-07-02 09:15:00.000000
# 3        web_form 2021-07-02 02:01:00 2021-07-02 09:44:00.000000
# 4        web_form 2021-07-02 02:41:00 2021-07-02 10:14:00.000000
# ...           ...                 ...                        ...
# 31515       email 2021-09-29 02:56:00 2021-09-29 14:56:44.829513
# 31516       email 2021-09-28 17:20:00 2021-09-29 15:19:44.829513
# 31517    web_form 2021-09-28 23:08:00 2021-09-29 15:57:44.829513
# 31518    web_form 2021-09-29 13:31:00 2021-09-29 16:14:44.829513
# 31519    web_form 2021-09-28 23:13:00 2021-09-29 16:37:44.829513
#
#                      action_date  customer_satisfaction  \
# 0     2021-07-02 08:50:00.000000                      1
# 1     2021-07-02 09:12:00.000000                      1
# ...

# %%
#Calculate of ticket volume for each team per week
# Week 1
dfrw1=df4[(df4['creation_date'] >= '2021-07-01' ) & (df4['creation_date'] <= '2021-07-04' )& (df4['user_team'] == 'orange' )]
dfbw1=df4[(df4['creation_date'] >= '2021-07-01' ) & (df4['creation_date'] <= '2021-07-04' )& (df4['user_team'] == 'blue' )]
dfgw1=df4[(df4['creation_date'] >= '2021-07-01' ) & (df4['creation_date'] <= '2021-07-04' )& (df4['user_team'] == 'green' )]
dfow1=df4[(df4['creation_date'] >= '2021-07-01' ) & (df4['creation_date'] <= '2021-07-04' )& (df4['user_team'] == 'orange' )]

# # Week 2
dfrw2=df4[(df4['creation_date'] >= '2021-07-05' ) & (df4['creation_date'] <= '2021-07-11' )& (df4['user_team'] == 'red' )]
dfbw2=df4[(df4['creation_date'] >= '2021-07-05' ) & (df4['creation_date'] <= '2021-07-11' )& (df4['user_team'] == 'blue' )]
dfgw2=df4[(df4['creation_date'] >= '2021-07-05' ) & (df4['creation_date'] <= '2021-07-11' )& (df4['user_team'] == 'green' )]
dfow2=df4[(df4['creation_date'] >= '2021-07-05' ) & (df4['creation_date'] <= '2021-07-11' )& (df4['user_team'] == 'orange' )]

# Week 3
dfrw3=df4[(df4['creation_date'] >= '2021-07-12' ) & (df4['creation_date'] <= '2021-07-18' )& (df4['user_team'] == 'red' )]
dfbw3=df4[(df4['creation_date'] >= '2021-07-12' ) & (df4['creation_date'] <= '2021-07-18' )& (df4['user_team'] == 'blue' )]
dfgw3=df4[(df4['creation_date'] >= '2021-07-12' ) & (df4['creation_date'] <= '2021-07-18' )& (df4['user_team'] == 'green' )]
dfow3=df4[(df4['creation_date'] >= '2021-07-12' ) & (df4['creation_date'] <= '2021-07-18' )& (df4['user_team'] == 'orange' )]

# Week 4
dfrw4=df4[(df4['creation_date'] >= '2021-07-19' ) & (df4['creation_date'] <= '2021-07-25' )& (df4['user_team'] == 'red' )]
dfbw4=df4[(df4['creation_date'] >= '2021-07-19' ) & (df4['creation_date'] <= '2021-07-25' )& (df4['user_team'] == 'blue' )]
dfgw4=df4[(df4['creation_date'] >= '2021-07-19' ) & (df4['creation_date'] <= '2021-07-25' )& (df4['user_team'] == 'green' )]
dfow4=df4[(df4['creation_date'] >= '2021-07-19' ) & (df4['creation_date'] <= '2021-07-25' )& (df4['user_team'] == 'orange' )]

# # Week 5
dfrw5=df4[(df4['creation_date'] >= '2021-07-26' ) & (df4['creation_date'] <= '2021-08-01' )& (df4['user_team'] == 'red' )]
dfbw5=df4[(df4['creation_date'] >= '2021-07-26' ) & (df4['creation_date'] <= '2021-08-01' )& (df4['user_team'] == 'blue' )]
dfgw5=df4[(df4['creation_date'] >= '2021-07-26' ) & (df4['creation_date'] <= '2021-08-01' )& (df4['user_team'] == 'green' )]
dfow5=df4[(df4['creation_date'] >= '2021-07-26' ) & (df4['creation_date'] <= '2021-08-01' )& (df4['user_team'] == 'orange' )]


# # Week 6
dfrw6=df4[(df4['creation_date'] >= '2021-08-02' ) & (df4['creation_date'] <= '2021-08-08' )& (df4['user_team'] == 'red' )]
dfbw6=df4[(df4['creation_date'] >= '2021-08-02' ) & (df4['creation_date'] <= '2021-08-08' )& (df4['user_team'] == 'blue' )]
dfgw6=df4[(df4['creation_date'] >= '2021-08-02' ) & (df4['creation_date'] <= '2021-08-08' )& (df4['user_team'] == 'green' )]
dfow6=df4[(df4['creation_date'] >= '2021-08-02' ) & (df4['creation_date'] <= '2021-08-08' )& (df4['user_team'] == 'orange' )]


# Week 7
dfrw7=df4[(df4['creation_date'] >= '2021-08-09' ) & (df4['creation_date'] <= '2021-08-15' )& (df4['user_team'] == 'red' )]
dfbw7=df4[(df4['creation_date'] >= '2021-08-09' ) & (df4['creation_date'] <= '2021-08-15' )& (df4['user_team'] == 'blue' )]
dfgw7=df4[(df4['creation_date'] >= '2021-08-09' ) & (df4['creation_date'] <= '2021-08-15' )& (df4['user_team'] == 'green' )]
dfow7=df4[(df4['creation_date'] >= '2021-08-09' ) & (df4['creation_date'] <= '2021-08-15' )& (df4['user_team'] == 'orange' )]

# Week 8
dfrw8=df4[(df4['creation_date'] >= '2021-08-16' ) & (df4['creation_date'] <= '2021-08-22' )& (df4['user_team'] == 'red' )]
dfbw8=df4[(df4['creation_date'] >= '2021-08-16' ) & (df4['creation_date'] <= '2021-08-22' )& (df4['user_team'] == 'blue' )]
dfgw8=df4[(df4['creation_date'] >= '2021-08-16' ) & (df4['creation_date'] <= '2021-08-22' )& (df4['user_team'] == 'green' )]
dfow8=df4[(df4['creation_date'] >= '2021-08-16' ) & (df4['creation_date'] <= '2021-08-22' )& (df4['user_team'] == 'orange' )]


# Week 9
dfrw9=df4[(df4['creation_date'] >= '2021-08-23' ) & (df4['creation_date'] <= '2021-08-29' )& (df4['user_team'] == 'red' )]
dfbw9=df4[(df4['creation_date'] >= '2021-08-23' ) & (df4['creation_date'] <= '2021-08-29' )& (df4['user_team'] == 'blue' )]
dfgw9=df4[(df4['creation_date'] >= '2021-08-23' ) & (df4['creation_date'] <= '2021-08-29' )& (df4['user_team'] == 'green' )]
dfow9=df4[(df4['creation_date'] >= '2021-08-23' ) & (df4['creation_date'] <= '2021-08-29' )& (df4['user_team'] == 'orange' )]


# Week 10
dfrw10=df4[(df4['creation_date'] >= '2021-08-30' ) & (df4['creation_date'] <= '2021-09-05' )& (df4['user_team'] == 'red' )]
dfbw10=df4[(df4['creation_date'] >= '2021-08-30' ) & (df4['creation_date'] <= '2021-09-05' )& (df4['user_team'] == 'blue' )]
dfgw10=df4[(df4['creation_date'] >= '2021-08-30' ) & (df4['creation_date'] <= '2021-09-05' )& (df4['user_team'] == 'green' )]
dfow10=df4[(df4['creation_date'] >= '2021-08-30' ) & (df4['creation_date'] <= '2021-09-05' )& (df4['user_team'] == 'orange' )]


# Week 11
dfrw11=df4[(df4['creation_date'] >= '2021-09-06' ) & (df4['creation_date'] <= '2021-09-12' )& (df4['user_team'] == 'red' )]
dfbw11=df4[(df4['creation_date'] >= '2021-09-06' ) & (df4['creation_date'] <= '2021-09-12' )& (df4['user_team'] == 'blue' )]
dfgw11=df4[(df4['creation_date'] >= '2021-09-06' ) & (df4['creation_date'] <= '2021-09-12' )& (df4['user_team'] == 'green' )]
dfow11=df4[(df4['creation_date'] >= '2021-09-06' ) & (df4['creation_date'] <= '2021-09-12' )& (df4['user_team'] == 'orange' )]


# Week 12
dfrw12=df4[(df4['creation_date'] >= '2021-09-13' ) & (df4['creation_date'] <= '2021-09-19' )& (df4['user_team'] == 'red' )]
dfbw12=df4[(df4['creation_date'] >= '2021-09-13' ) & (df4['creation_date'] <= '2021-09-19' )& (df4['user_team'] == 'blue' )]
dfgw12=df4[(df4['creation_date'] >= '2021-09-13' ) & (df4['creation_date'] <= '2021-09-19' )& (df4['user_team'] == 'green' )]
dfow12=df4[(df4['creation_date'] >= '2021-09-13' ) & (df4['creation_date'] <= '2021-09-19' )& (df4['user_team'] == 'orange' )]
 


# Week 13
dfrw13=df4[(df4['creation_date'] >= '2021-09-20' )  &(df4['user_team'] == 'red' )]
dfbw13=df4[(df4['creation_date'] >= '2021-09-20' ) & (df4['user_team'] == 'blue' )]
dfgw13=df4[(df4['creation_date'] >= '2021-09-20' ) & (df4['user_team'] == 'green' )]
dfow13=df4[(df4['creation_date'] >= '2021-09-20' ) & (df4['user_team'] == 'orange' )]

# %%
import matplotlib.pyplot as plt
import seaborn as sns
fig, ax = plt.subplots(figsize=(10,8))
sns.set_theme(style="ticks")
hue = ['Red Team', 'Blue Team', 'Green Team', 'Orange Team']
xr = ['2021-07-04', '2021-07-11', '2021-07-18','2021-07-25','2021-08-01','2021-08-08','2021-08-15','2021-08-22','2021-08-29','2021-09-05','2021-09-12','2021-09-19','2021-09-26']
yr = [184, 472, 472,437, 476, 453,459, 472, 450,474, 444, 479,737]
ax.tick_params(axis='x',rotation=90 ) 
sns.lineplot(xr, yr, marker='o', color='red')

xb = ['2021-07-04', '2021-07-11', '2021-07-18','2021-07-25','2021-08-01','2021-08-08','2021-08-15','2021-08-22','2021-08-29','2021-09-05','2021-09-12','2021-09-19','2021-09-26']
yb = [188, 497, 496,517, 488, 483,471, 513, 477,494, 461, 407,401]
sns.lineplot( xb, yb, linewidth=2, marker='o', color='blue')

xg = ['2021-07-04', '2021-07-11', '2021-07-18','2021-07-25','2021-08-01','2021-08-08','2021-08-15','2021-08-22','2021-08-29','2021-09-05','2021-09-12','2021-09-19','2021-09-26']
yg = [302, 804, 830,858, 852, 855,820, 834, 767,875, 820, 807,1273]
sns.lineplot( xg, yg, linewidth=2, marker='o', color='green')

xo = ['2021-07-04', '2021-07-11', '2021-07-18','2021-07-25','2021-08-01','2021-08-08','2021-08-15','2021-08-22','2021-08-29','2021-09-05','2021-09-12','2021-09-19','2021-09-26']
yo = [184, 463, 434,469, 455, 420,409, 369, 357,339, 273, 235,234]
sns.lineplot( xo, yo, linewidth=2, marker='o', color='orange')
ax.set_yticks([0,100,200,300,400,500,600,700,800,900,1000,1100,1200,1300])
ax.set_title('Ticket Volume ', fontsize = 22)
plt.xlabel("Weeks", fontsize = 18)
plt.ylabel("Ticket Numbers", fontsize = 18)
ax.legend(hue)
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ...

# %% [markdown]
# ## 4.	Ticket Backlog
# ### Ticket Backlog refers to unresolved customer support requests in a particular time frame. These tickets remain unresolved beyond the typical response time either because of team member performance, ticket volume, and/or dependencies and complexities that require additional time. In this section, I have considered 1440 minutes or a day​.

# %%
df4=df
df4
# Out:
#       ticket_type       creation_date                  view_date  \
# 0       live_chat 2021-07-02 08:36:00 2021-07-02 08:36:00.000000
# 1        web_form 2021-07-02 02:37:00 2021-07-02 08:51:00.000000
# 2        web_form 2021-07-02 02:50:00 2021-07-02 09:15:00.000000
# 3        web_form 2021-07-02 02:01:00 2021-07-02 09:44:00.000000
# 4        web_form 2021-07-02 02:41:00 2021-07-02 10:14:00.000000
# ...           ...                 ...                        ...
# 31515       email 2021-09-29 02:56:00 2021-09-29 14:56:44.829513
# 31516       email 2021-09-28 17:20:00 2021-09-29 15:19:44.829513
# 31517    web_form 2021-09-28 23:08:00 2021-09-29 15:57:44.829513
# 31518    web_form 2021-09-29 13:31:00 2021-09-29 16:14:44.829513
# 31519    web_form 2021-09-28 23:13:00 2021-09-29 16:37:44.829513
#
#                      action_date  customer_satisfaction  \
# 0     2021-07-02 08:50:00.000000                      1
# 1     2021-07-02 09:12:00.000000                      1
# ...

# %%
# df5['response_time_minutes'] = (df5['action_date'] - df5['creation_date']).astype('timedelta64[m]')

# %%
df4['First_time_action'] = (df4['action_date'] - df4['creation_date']).astype('timedelta64[m]')

# %%
#Calculate of All ticket volume

# Week 1
dfcd1=df4[(df4['creation_date'] >= '2021-07-01' ) & (df4['creation_date'] <= '2021-07-04' )]
# # Week 2
dfcd2=df4[(df4['creation_date'] >= '2021-07-05' ) & (df4['creation_date'] <= '2021-07-11' )]
# Week 3
dfcd3=df4[(df4['creation_date'] >= '2021-07-12' ) & (df4['creation_date'] <= '2021-07-18' )]

# Week 4

dfcd4=df4[(df4['creation_date'] >= '2021-07-19' ) & (df4['creation_date'] <= '2021-07-25' )]

# # Week 5
dfcd5=df4[(df4['creation_date'] >= '2021-07-26' ) & (df4['creation_date'] <= '2021-08-01' )]


# # Week 6
dfcd6=df4[(df4['creation_date'] >= '2021-08-02' ) & (df4['creation_date'] <= '2021-08-08' )]


# Week 7
dfcd7=df4[(df4['creation_date'] >= '2021-08-09' ) & (df4['creation_date'] <= '2021-08-15' )]



# Week 8
dfcd8=df4[(df4['creation_date'] >= '2021-08-16' ) & (df4['creation_date'] <= '2021-08-22' )]


# Week 9
dfcd9=df4[(df4['creation_date'] >= '2021-08-23' ) & (df4['creation_date'] <= '2021-08-29' )]


# Week 10
dfcd10=df4[(df4['creation_date'] >= '2021-08-30' ) & (df4['creation_date'] <= '2021-09-05' )]


# Week 11
dfcd11=df4[(df4['creation_date'] >= '2021-09-06' ) & (df4['creation_date'] <= '2021-09-12' )]


# Week 12
dfcd12=df4[(df4['creation_date'] >= '2021-09-13' ) & (df4['creation_date'] <= '2021-09-19' )]


# Week 13
dfcd13=df4[(df4['creation_date'] >= '2021-09-20' ) ]
# dfcd13.count()



#Calculate of All Resolved ticket 

# Week 1
dfrt1=df4[(df4['creation_date'] >= '2021-07-01' ) & (df4['creation_date'] <= '2021-07-04' )& (df4['customer_problem_resolved'] == True )]


# # Week 2
dfrt2=df4[(df4['creation_date'] >= '2021-07-05' ) & (df4['creation_date'] <= '2021-07-11' )& (df4['customer_problem_resolved'] == True )]


# Week 3
dfrt3=df4[(df4['creation_date'] >= '2021-07-12' ) & (df4['creation_date'] <= '2021-07-18' )& (df4['customer_problem_resolved'] == True )]


# Week 4
dfrt4=df4[(df4['creation_date'] >= '2021-07-19' ) & (df4['creation_date'] <= '2021-07-25' )& (df4['customer_problem_resolved'] == True )]



# # Week 5
dfrt5=df4[(df4['creation_date'] >= '2021-07-26' ) & (df4['creation_date'] <= '2021-08-01' )& (df4['customer_problem_resolved'] == True )]


# # Week 6
dfrt6=df4[(df4['creation_date'] >= '2021-08-02' ) & (df4['creation_date'] <= '2021-08-08' )& (df4['customer_problem_resolved'] == True )]


# Week 7
dfrt7=df4[(df4['creation_date'] >= '2021-08-09' ) & (df4['creation_date'] <= '2021-08-15' )& (df4['customer_problem_resolved'] == True )]



# Week 8
dfrt8=df4[(df4['creation_date'] >= '2021-08-16' ) & (df4['creation_date'] <= '2021-08-22' )& (df4['customer_problem_resolved'] == True )]


# Week 9
dfrt9=df4[(df4['creation_date'] >= '2021-08-23' ) & (df4['creation_date'] <= '2021-08-29' )& (df4['customer_problem_resolved'] == True )]


# Week 10
dfrt10=df4[(df4['creation_date'] >= '2021-08-30' ) & (df4['creation_date'] <= '2021-09-05' )& (df4['customer_problem_resolved'] == True )]


# Week 11
dfrt11=df4[(df4['creation_date'] >= '2021-09-06' ) & (df4['creation_date'] <= '2021-09-12' )& (df4['customer_problem_resolved'] == True )]


# Week 12
dfrt12=df4[(df4['creation_date'] >= '2021-09-13' ) & (df4['creation_date'] <= '2021-09-19' )& (df4['customer_problem_resolved'] == True )]


# Week 13
dfrt13=df4[(df4['creation_date'] >= '2021-09-20' ) & (df4['customer_problem_resolved'] == True )]
# dfrt13.count()


#Calculate of All UnResolved ticket more than 1440 Minutes

# Week 1
dffta1=df4[(df4['creation_date'] >= '2021-07-01' ) & (df4['creation_date'] <= '2021-07-04' )& (df4['customer_problem_resolved'] == False ) & (df4['First_time_action'] >= 1440.0 )]

# # Week 2
dffta2=df4[(df4['creation_date'] >= '2021-07-05' ) & (df4['creation_date'] <= '2021-07-11' )& (df4['customer_problem_resolved'] == False ) & (df4['First_time_action'] >= 1440.0 )]


# Week 3
dffta3=df4[(df4['creation_date'] >= '2021-07-12' ) & (df4['creation_date'] <= '2021-07-18' )& (df4['customer_problem_resolved'] == False ) & (df4['First_time_action'] >= 1440.0 )]


# Week 4
dffta4=df4[(df4['creation_date'] >= '2021-07-19' ) & (df4['creation_date'] <= '2021-07-25' )& (df4['customer_problem_resolved'] == False ) & (df4['First_time_action'] >= 1440.0 )]



# # Week 5
dffta5=df4[(df4['creation_date'] >= '2021-07-26' ) & (df4['creation_date'] <= '2021-08-01' )& (df4['customer_problem_resolved'] == False ) & (df4['First_time_action'] >= 1440.0 )]


# # Week 6
dffta6=df4[(df4['creation_date'] >= '2021-08-02' ) & (df4['creation_date'] <= '2021-08-08' )& (df4['customer_problem_resolved'] == False ) & (df4['First_time_action'] >= 1440.0 )]


# Week 7
dffta7=df4[(df4['creation_date'] >= '2021-08-09' ) & (df4['creation_date'] <= '2021-08-15' )& (df4['customer_problem_resolved'] == False ) & (df4['First_time_action'] >= 1440.0 )]



# Week 8
dffta8=df4[(df4['creation_date'] >= '2021-08-16' ) & (df4['creation_date'] <= '2021-08-22' )& (df4['customer_problem_resolved'] == False ) & (df4['First_time_action'] >= 1440.0 )]


# Week 9
dffta9=df4[(df4['creation_date'] >= '2021-08-23' ) & (df4['creation_date'] <= '2021-08-29' )& (df4['customer_problem_resolved'] == False ) & (df4['First_time_action'] >= 1440.0 )]


# Week 10
dffta10=df4[(df4['creation_date'] >= '2021-08-30' ) & (df4['creation_date'] <= '2021-09-05' )& (df4['customer_problem_resolved'] == False ) & (df4['First_time_action'] >= 1440.0 )]


# Week 11
dffta11=df4[(df4['creation_date'] >= '2021-09-06' ) & (df4['creation_date'] <= '2021-09-12' )& (df4['customer_problem_resolved'] == False ) & (df4['First_time_action'] >= 1440.0 )]


# Week 12
dffta12=df4[(df4['creation_date'] >= '2021-09-13' ) & (df4['creation_date'] <= '2021-09-19' )& (df4['customer_problem_resolved'] == False ) & (df4['First_time_action'] >= 1440.0 )]


# Week 13
dffta13=df4[(df4['creation_date'] >= '2021-09-20' ) & (df4['customer_problem_resolved'] == False )& (df4['First_time_action'] >= 1440.0 )]
# dffta13.count()

# %%
df4
# Out:
#       ticket_type       creation_date                  view_date  \
# 0       live_chat 2021-07-02 08:36:00 2021-07-02 08:36:00.000000
# 1        web_form 2021-07-02 02:37:00 2021-07-02 08:51:00.000000
# 2        web_form 2021-07-02 02:50:00 2021-07-02 09:15:00.000000
# 3        web_form 2021-07-02 02:01:00 2021-07-02 09:44:00.000000
# 4        web_form 2021-07-02 02:41:00 2021-07-02 10:14:00.000000
# ...           ...                 ...                        ...
# 31515       email 2021-09-29 02:56:00 2021-09-29 14:56:44.829513
# 31516       email 2021-09-28 17:20:00 2021-09-29 15:19:44.829513
# 31517    web_form 2021-09-28 23:08:00 2021-09-29 15:57:44.829513
# 31518    web_form 2021-09-29 13:31:00 2021-09-29 16:14:44.829513
# 31519    web_form 2021-09-28 23:13:00 2021-09-29 16:37:44.829513
#
#                      action_date  customer_satisfaction  \
# 0     2021-07-02 08:50:00.000000                      1
# 1     2021-07-02 09:12:00.000000                      1
# ...

# %%
#Calculate of All ticket volume for Red

# Week 1 All ticket volume for Red team
dfcdr1=df4[(df4['creation_date'] >= '2021-07-01' ) & (df4['creation_date'] <= '2021-07-04' )& (df4['user_team'] == 'red' )]
# # Week 2
dfcdr2=df4[(df4['creation_date'] >= '2021-07-05' ) & (df4['creation_date'] <= '2021-07-11' )& (df4['user_team'] == 'red' )]
# Week 3
dfcdr3=df4[(df4['creation_date'] >= '2021-07-12' ) & (df4['creation_date'] <= '2021-07-18' )& (df4['user_team'] == 'red' )]

# Week 4
dfcdr4=df4[(df4['creation_date'] >= '2021-07-19' ) & (df4['creation_date'] <= '2021-07-25' )& (df4['user_team'] == 'red' )]

# # Week 5
dfcdr5=df4[(df4['creation_date'] >= '2021-07-26' ) & (df4['creation_date'] <= '2021-08-01' )& (df4['user_team'] == 'red' )]

# # Week 6
dfcdr6=df4[(df4['creation_date'] >= '2021-08-02' ) & (df4['creation_date'] <= '2021-08-08' )& (df4['user_team'] == 'red' )]

# Week 7
dfcdr7=df4[(df4['creation_date'] >= '2021-08-09' ) & (df4['creation_date'] <= '2021-08-15' )& (df4['user_team'] == 'red' )]

# Week 8
dfcdr8=df4[(df4['creation_date'] >= '2021-08-16' ) & (df4['creation_date'] <= '2021-08-22' )& (df4['user_team'] == 'red' )]

# Week 9
dfcdr9=df4[(df4['creation_date'] >= '2021-08-23' ) & (df4['creation_date'] <= '2021-08-29' )& (df4['user_team'] == 'red' )]

# Week 10
dfcdr10=df4[(df4['creation_date'] >= '2021-08-30' ) & (df4['creation_date'] <= '2021-09-05' )& (df4['user_team'] == 'red' )]

# Week 11
dfcdr11=df4[(df4['creation_date'] >= '2021-09-06' ) & (df4['creation_date'] <= '2021-09-12' )& (df4['user_team'] == 'red' )]

# Week 12
dfcdr12=df4[(df4['creation_date'] >= '2021-09-13' ) & (df4['creation_date'] <= '2021-09-19' )& (df4['user_team'] == 'red' )]

# Week 13
dfcdr13=df4[(df4['creation_date'] >= '2021-09-20' )& (df4['user_team'] == 'red' ) ]




#Calculate of All Resolved ticket for Red team

# Week 1
dfrtr1=df4[(df4['creation_date'] >= '2021-07-01' ) & (df4['creation_date'] <= '2021-07-04' )& (df4['customer_problem_resolved'] == True )& (df4['user_team'] == 'red' )]


# # Week 2
dfrtr2=df4[(df4['creation_date'] >= '2021-07-05' ) & (df4['creation_date'] <= '2021-07-11' )& (df4['customer_problem_resolved'] == True )& (df4['user_team'] == 'red' )]


# Week 3
dfrtr3=df4[(df4['creation_date'] >= '2021-07-12' ) & (df4['creation_date'] <= '2021-07-18' )& (df4['customer_problem_resolved'] == True )& (df4['user_team'] == 'red' )]


# Week 4
dfrtr4=df4[(df4['creation_date'] >= '2021-07-19' ) & (df4['creation_date'] <= '2021-07-25' )& (df4['customer_problem_resolved'] == True )& (df4['user_team'] == 'red' )]



# # Week 5
dfrtr5=df4[(df4['creation_date'] >= '2021-07-26' ) & (df4['creation_date'] <= '2021-08-01' )& (df4['customer_problem_resolved'] == True )& (df4['user_team'] == 'red' )]


# # Week 6
dfrtr6=df4[(df4['creation_date'] >= '2021-08-02' ) & (df4['creation_date'] <= '2021-08-08' )& (df4['customer_problem_resolved'] == True )& (df4['user_team'] == 'red' )]


# Week 7
dfrtr7=df4[(df4['creation_date'] >= '2021-08-09' ) & (df4['creation_date'] <= '2021-08-15' )& (df4['customer_problem_resolved'] == True )& (df4['user_team'] == 'red' )]



# Week 8
dfrtr8=df4[(df4['creation_date'] >= '2021-08-16' ) & (df4['creation_date'] <= '2021-08-22' )& (df4['customer_problem_resolved'] == True )& (df4['user_team'] == 'red' )]


# Week 9
dfrtr9=df4[(df4['creation_date'] >= '2021-08-23' ) & (df4['creation_date'] <= '2021-08-29' )& (df4['customer_problem_resolved'] == True )& (df4['user_team'] == 'red' )]


# Week 10
dfrtr10=df4[(df4['creation_date'] >= '2021-08-30' ) & (df4['creation_date'] <= '2021-09-05' )& (df4['customer_problem_resolved'] == True )& (df4['user_team'] == 'red' )]


# Week 11
dfrtr11=df4[(df4['creation_date'] >= '2021-09-06' ) & (df4['creation_date'] <= '2021-09-12' )& (df4['customer_problem_resolved'] == True )& (df4['user_team'] == 'red' )]


# Week 12
dfrtr12=df4[(df4['creation_date'] >= '2021-09-13' ) & (df4['creation_date'] <= '2021-09-19' )& (df4['customer_problem_resolved'] == True )& (df4['user_team'] == 'red' )]


# Week 13
dfrtr13=df4[(df4['creation_date'] >= '2021-09-20' ) & (df4['customer_problem_resolved'] == True )& (df4['user_team'] == 'red' )]


#Calculate of All UnResolved ticket more than 1440 Minutes for Red Team

# Week 1
dfftar1=df4[(df4['creation_date'] >= '2021-07-01' ) & (df4['creation_date'] <= '2021-07-04' )& (df4['customer_problem_resolved'] == False )& (df4['user_team'] == 'red' ) & (df4['First_time_action'] >= 1440.0 )]

# # Week 2
dfftar2=df4[(df4['creation_date'] >= '2021-07-05' ) & (df4['creation_date'] <= '2021-07-11' )& (df4['customer_problem_resolved'] == False ) & (df4['First_time_action'] >= 1440.0 )& (df4['user_team'] == 'red' )]


# Week 3
dfftar3=df4[(df4['creation_date'] >= '2021-07-12' ) & (df4['creation_date'] <= '2021-07-18' )& (df4['customer_problem_resolved'] == False ) & (df4['First_time_action'] >= 1440.0 )& (df4['user_team'] == 'red' )]


# Week 4
dfftar4=df4[(df4['creation_date'] >= '2021-07-19' ) & (df4['creation_date'] <= '2021-07-25' )& (df4['customer_problem_resolved'] == False ) & (df4['First_time_action'] >= 1440.0 )& (df4['user_team'] == 'red' )]



# # Week 5
dfftar5=df4[(df4['creation_date'] >= '2021-07-26' ) & (df4['creation_date'] <= '2021-08-01' )& (df4['customer_problem_resolved'] == False ) & (df4['First_time_action'] >= 1440.0 )& (df4['user_team'] == 'red' )]


# # Week 6
dfftar6=df4[(df4['creation_date'] >= '2021-08-02' ) & (df4['creation_date'] <= '2021-08-08' )& (df4['customer_problem_resolved'] == False ) & (df4['First_time_action'] >= 1440.0 )& (df4['user_team'] == 'red' )]


# Week 7
dfftar7=df4[(df4['creation_date'] >= '2021-08-09' ) & (df4['creation_date'] <= '2021-08-15' )& (df4['customer_problem_resolved'] == False ) & (df4['First_time_action'] >= 1440.0 )& (df4['user_team'] == 'red' )]



# Week 8
dfftar8=df4[(df4['creation_date'] >= '2021-08-16' ) & (df4['creation_date'] <= '2021-08-22' )& (df4['customer_problem_resolved'] == False ) & (df4['First_time_action'] >= 1440.0 )& (df4['user_team'] == 'red' )]


# Week 9
dfftar9=df4[(df4['creation_date'] >= '2021-08-23' ) & (df4['creation_date'] <= '2021-08-29' )& (df4['customer_problem_resolved'] == False ) & (df4['First_time_action'] >= 1440.0 )& (df4['user_team'] == 'red' )]


# Week 10
dfftar10=df4[(df4['creation_date'] >= '2021-08-30' ) & (df4['creation_date'] <= '2021-09-05' )& (df4['customer_problem_resolved'] == False ) & (df4['First_time_action'] >= 1440.0 )& (df4['user_team'] == 'red' )]


# Week 11
dfftar11=df4[(df4['creation_date'] >= '2021-09-06' ) & (df4['creation_date'] <= '2021-09-12' )& (df4['customer_problem_resolved'] == False ) & (df4['First_time_action'] >= 1440.0 )& (df4['user_team'] == 'red' )]


# Week 12
dfftar12=df4[(df4['creation_date'] >= '2021-09-13' ) & (df4['creation_date'] <= '2021-09-19' )& (df4['customer_problem_resolved'] == False ) & (df4['First_time_action'] >= 1440.0 )& (df4['user_team'] == 'red' )]


# Week 13
dfftar13=df4[(df4['creation_date'] >= '2021-09-20' ) & (df4['customer_problem_resolved'] == False )& (df4['First_time_action'] >= 1440.0 )& (df4['user_team'] == 'red' )]

# %%
#Calculate of All ticket volume for Blue

# Week 1 All ticket volume for blue team
dfcdb1=df4[(df4['creation_date'] >= '2021-07-01' ) & (df4['creation_date'] <= '2021-07-04' )& (df4['user_team'] == 'blue' )]
# # Week 2
dfcdb2=df4[(df4['creation_date'] >= '2021-07-05' ) & (df4['creation_date'] <= '2021-07-11' )& (df4['user_team'] == 'blue' )]

# Week 3
dfcdb3=df4[(df4['creation_date'] >= '2021-07-12' ) & (df4['creation_date'] <= '2021-07-18' )& (df4['user_team'] == 'blue' )]


# Week 4
dfcdb4=df4[(df4['creation_date'] >= '2021-07-19' ) & (df4['creation_date'] <= '2021-07-25' )& (df4['user_team'] == 'blue' )]

# # Week 5
dfcdb5=df4[(df4['creation_date'] >= '2021-07-26' ) & (df4['creation_date'] <= '2021-08-01' )& (df4['user_team'] == 'blue' )]

# # Week 6
dfcdb6=df4[(df4['creation_date'] >= '2021-08-02' ) & (df4['creation_date'] <= '2021-08-08' )& (df4['user_team'] == 'blue' )]

# Week 7
dfcdb7=df4[(df4['creation_date'] >= '2021-08-09' ) & (df4['creation_date'] <= '2021-08-15' )& (df4['user_team'] == 'blue' )]

# Week 8
dfcdb8=df4[(df4['creation_date'] >= '2021-08-16' ) & (df4['creation_date'] <= '2021-08-22' )& (df4['user_team'] == 'blue' )]

# Week 9
dfcdb9=df4[(df4['creation_date'] >= '2021-08-23' ) & (df4['creation_date'] <= '2021-08-29' )& (df4['user_team'] == 'blue' )]

# Week 10
dfcdb10=df4[(df4['creation_date'] >= '2021-08-30' ) & (df4['creation_date'] <= '2021-09-05' )& (df4['user_team'] == 'blue' )]

# Week 11
dfcdb11=df4[(df4['creation_date'] >= '2021-09-06' ) & (df4['creation_date'] <= '2021-09-12' )& (df4['user_team'] == 'blue' )]

# Week 12
dfcdb12=df4[(df4['creation_date'] >= '2021-09-13' ) & (df4['creation_date'] <= '2021-09-19' )& (df4['user_team'] == 'blue' )]

# Week 13
dfcdb13=df4[(df4['creation_date'] >= '2021-09-20' )& (df4['user_team'] == 'blue' ) ]




#Calculate of All Resolved ticket for blue team

# Week 1
dfrtb1=df4[(df4['creation_date'] >= '2021-07-01' ) & (df4['creation_date'] <= '2021-07-04' )& (df4['customer_problem_resolved'] == True )& (df4['user_team'] == 'blue' )]

# # Week 2
dfrtb2=df4[(df4['creation_date'] >= '2021-07-05' ) & (df4['creation_date'] <= '2021-07-11' )& (df4['customer_problem_resolved'] == True )& (df4['user_team'] == 'blue' )]


# Week 3
dfrtb3=df4[(df4['creation_date'] >= '2021-07-12' ) & (df4['creation_date'] <= '2021-07-18' )& (df4['customer_problem_resolved'] == True )& (df4['user_team'] == 'blue' )]


# Week 4
dfrtb4=df4[(df4['creation_date'] >= '2021-07-19' ) & (df4['creation_date'] <= '2021-07-25' )& (df4['customer_problem_resolved'] == True )& (df4['user_team'] == 'blue' )]



# # Week 5
dfrtb5=df4[(df4['creation_date'] >= '2021-07-26' ) & (df4['creation_date'] <= '2021-08-01' )& (df4['customer_problem_resolved'] == True )& (df4['user_team'] == 'blue' )]


# # Week 6
dfrtb6=df4[(df4['creation_date'] >= '2021-08-02' ) & (df4['creation_date'] <= '2021-08-08' )& (df4['customer_problem_resolved'] == True )& (df4['user_team'] == 'blue' )]


# Week 7
dfrtb7=df4[(df4['creation_date'] >= '2021-08-09' ) & (df4['creation_date'] <= '2021-08-15' )& (df4['customer_problem_resolved'] == True )& (df4['user_team'] == 'blue' )]



# Week 8
dfrtb8=df4[(df4['creation_date'] >= '2021-08-16' ) & (df4['creation_date'] <= '2021-08-22' )& (df4['customer_problem_resolved'] == True )& (df4['user_team'] == 'blue' )]


# Week 9
dfrtb9=df4[(df4['creation_date'] >= '2021-08-23' ) & (df4['creation_date'] <= '2021-08-29' )& (df4['customer_problem_resolved'] == True )& (df4['user_team'] == 'blue' )]


# Week 10
dfrtb10=df4[(df4['creation_date'] >= '2021-08-30' ) & (df4['creation_date'] <= '2021-09-05' )& (df4['customer_problem_resolved'] == True )& (df4['user_team'] == 'blue' )]


# Week 11
dfrtb11=df4[(df4['creation_date'] >= '2021-09-06' ) & (df4['creation_date'] <= '2021-09-12' )& (df4['customer_problem_resolved'] == True )& (df4['user_team'] == 'blue' )]


# Week 12
dfrtb12=df4[(df4['creation_date'] >= '2021-09-13' ) & (df4['creation_date'] <= '2021-09-19' )& (df4['customer_problem_resolved'] == True )& (df4['user_team'] == 'blue' )]


# Week 13
dfrtb13=df4[(df4['creation_date'] >= '2021-09-20' ) & (df4['customer_problem_resolved'] == True )& (df4['user_team'] == 'blue' )]


#Calculate of All UnResolved ticket more than 1440 Minutes for Red Team

# Week 1
dfftab1=df4[(df4['creation_date'] >= '2021-07-01' ) & (df4['creation_date'] <= '2021-07-04' )& (df4['customer_problem_resolved'] == False )& (df4['user_team'] == 'blue' ) & (df4['First_time_action'] >= 1440.0 )]

# # Week 2
dfftab2=df4[(df4['creation_date'] >= '2021-07-05' ) & (df4['creation_date'] <= '2021-07-11' )& (df4['customer_problem_resolved'] == False ) & (df4['First_time_action'] >= 1440.0 )& (df4['user_team'] == 'blue' )]


# Week 3
dfftab3=df4[(df4['creation_date'] >= '2021-07-12' ) & (df4['creation_date'] <= '2021-07-18' )& (df4['customer_problem_resolved'] == False ) & (df4['First_time_action'] >= 1440.0 )& (df4['user_team'] == 'blue' )]


# Week 4
dfftab4=df4[(df4['creation_date'] >= '2021-07-19' ) & (df4['creation_date'] <= '2021-07-25' )& (df4['customer_problem_resolved'] == False ) & (df4['First_time_action'] >= 1440.0 )& (df4['user_team'] == 'blue' )]



# # Week 5
dfftab5=df4[(df4['creation_date'] >= '2021-07-26' ) & (df4['creation_date'] <= '2021-08-01' )& (df4['customer_problem_resolved'] == False ) & (df4['First_time_action'] >= 1440.0 )& (df4['user_team'] == 'blue' )]


# # Week 6
dfftab6=df4[(df4['creation_date'] >= '2021-08-02' ) & (df4['creation_date'] <= '2021-08-08' )& (df4['customer_problem_resolved'] == False ) & (df4['First_time_action'] >= 1440.0 )& (df4['user_team'] == 'blue' )]


# Week 7
dfftab7=df4[(df4['creation_date'] >= '2021-08-09' ) & (df4['creation_date'] <= '2021-08-15' )& (df4['customer_problem_resolved'] == False ) & (df4['First_time_action'] >= 1440.0 )& (df4['user_team'] == 'blue' )]



# Week 8
dfftab8=df4[(df4['creation_date'] >= '2021-08-16' ) & (df4['creation_date'] <= '2021-08-22' )& (df4['customer_problem_resolved'] == False ) & (df4['First_time_action'] >= 1440.0 )& (df4['user_team'] == 'blue' )]


# Week 9
dfftab9=df4[(df4['creation_date'] >= '2021-08-23' ) & (df4['creation_date'] <= '2021-08-29' )& (df4['customer_problem_resolved'] == False ) & (df4['First_time_action'] >= 1440.0 )& (df4['user_team'] == 'blue' )]


# Week 10
dfftab10=df4[(df4['creation_date'] >= '2021-08-30' ) & (df4['creation_date'] <= '2021-09-05' )& (df4['customer_problem_resolved'] == False ) & (df4['First_time_action'] >= 1440.0 )& (df4['user_team'] == 'blue' )]


# Week 11
dfftab11=df4[(df4['creation_date'] >= '2021-09-06' ) & (df4['creation_date'] <= '2021-09-12' )& (df4['customer_problem_resolved'] == False ) & (df4['First_time_action'] >= 1440.0 )& (df4['user_team'] == 'blue' )]


# Week 12
dfftab12=df4[(df4['creation_date'] >= '2021-09-13' ) & (df4['creation_date'] <= '2021-09-19' )& (df4['customer_problem_resolved'] == False ) & (df4['First_time_action'] >= 1440.0 )& (df4['user_team'] == 'blue' )]


# Week 13
dfftab13=df4[(df4['creation_date'] >= '2021-09-20' ) & (df4['customer_problem_resolved'] == False )& (df4['First_time_action'] >= 1440.0 )& (df4['user_team'] == 'blue' )]

# %%
#Calculate of All ticket volume for Green

# Week 1 All ticket volume for green team
dfcdg1=df4[(df4['creation_date'] >= '2021-07-01' ) & (df4['creation_date'] <= '2021-07-04' )& (df4['user_team'] == 'green' )]


# # Week 2
dfcdg2=df4[(df4['creation_date'] >= '2021-07-05' ) & (df4['creation_date'] <= '2021-07-11' )& (df4['user_team'] == 'green' )]

# Week 3
dfcdg3=df4[(df4['creation_date'] >= '2021-07-12' ) & (df4['creation_date'] <= '2021-07-18' )& (df4['user_team'] == 'green' )]


# Week 4
dfcdg4=df4[(df4['creation_date'] >= '2021-07-19' ) & (df4['creation_date'] <= '2021-07-25' )& (df4['user_team'] == 'green' )]


# # Week 5
dfcdg5=df4[(df4['creation_date'] >= '2021-07-26' ) & (df4['creation_date'] <= '2021-08-01' )& (df4['user_team'] == 'green' )]

# # Week 6
dfcdg6=df4[(df4['creation_date'] >= '2021-08-02' ) & (df4['creation_date'] <= '2021-08-08' )& (df4['user_team'] == 'green' )]


# Week 7
dfcdg7=df4[(df4['creation_date'] >= '2021-08-09' ) & (df4['creation_date'] <= '2021-08-15' )& (df4['user_team'] == 'green' )]

# Week 8
dfcdg8=df4[(df4['creation_date'] >= '2021-08-16' ) & (df4['creation_date'] <= '2021-08-22' )& (df4['user_team'] == 'green' )]

# Week 9
dfcdg9=df4[(df4['creation_date'] >= '2021-08-23' ) & (df4['creation_date'] <= '2021-08-29' )& (df4['user_team'] == 'green' )]


# Week 10
dfcdg10=df4[(df4['creation_date'] >= '2021-08-30' ) & (df4['creation_date'] <= '2021-09-05' )& (df4['user_team'] == 'green' )]

# Week 11
dfcdg11=df4[(df4['creation_date'] >= '2021-09-06' ) & (df4['creation_date'] <= '2021-09-12' )& (df4['user_team'] == 'green' )]

# Week 12
dfcdg12=df4[(df4['creation_date'] >= '2021-09-13' ) & (df4['creation_date'] <= '2021-09-19' )& (df4['user_team'] == 'green' )]

# Week 13
dfcdg13=df4[(df4['creation_date'] >= '2021-09-20' )& (df4['user_team'] == 'green' ) ]




#Calculate of All Resolved ticket for green team

# Week 1
dfrtg1=df4[(df4['creation_date'] >= '2021-07-01' ) & (df4['creation_date'] <= '2021-07-04' )& (df4['customer_problem_resolved'] == True )& (df4['user_team'] == 'green' )]

# # Week 2
dfrtg2=df4[(df4['creation_date'] >= '2021-07-05' ) & (df4['creation_date'] <= '2021-07-11' )& (df4['customer_problem_resolved'] == True )& (df4['user_team'] == 'green' )]


# Week 3
dfrtg3=df4[(df4['creation_date'] >= '2021-07-12' ) & (df4['creation_date'] <= '2021-07-18' )& (df4['customer_problem_resolved'] == True )& (df4['user_team'] == 'green' )]


# Week 4
dfrtg4=df4[(df4['creation_date'] >= '2021-07-19' ) & (df4['creation_date'] <= '2021-07-25' )& (df4['customer_problem_resolved'] == True )& (df4['user_team'] == 'green' )]



# # Week 5
dfrtg5=df4[(df4['creation_date'] >= '2021-07-26' ) & (df4['creation_date'] <= '2021-08-01' )& (df4['customer_problem_resolved'] == True )& (df4['user_team'] == 'green' )]


# # Week 6
dfrtg6=df4[(df4['creation_date'] >= '2021-08-02' ) & (df4['creation_date'] <= '2021-08-08' )& (df4['customer_problem_resolved'] == True )& (df4['user_team'] == 'green' )]


# Week 7
dfrtg7=df4[(df4['creation_date'] >= '2021-08-09' ) & (df4['creation_date'] <= '2021-08-15' )& (df4['customer_problem_resolved'] == True )& (df4['user_team'] == 'green' )]



# Week 8
dfrtg8=df4[(df4['creation_date'] >= '2021-08-16' ) & (df4['creation_date'] <= '2021-08-22' )& (df4['customer_problem_resolved'] == True )& (df4['user_team'] == 'green' )]


# Week 9
dfrtg9=df4[(df4['creation_date'] >= '2021-08-23' ) & (df4['creation_date'] <= '2021-08-29' )& (df4['customer_problem_resolved'] == True )& (df4['user_team'] == 'green' )]


# Week 10
dfrtg10=df4[(df4['creation_date'] >= '2021-08-30' ) & (df4['creation_date'] <= '2021-09-05' )& (df4['customer_problem_resolved'] == True )& (df4['user_team'] == 'green' )]


# Week 11
dfrtg11=df4[(df4['creation_date'] >= '2021-09-06' ) & (df4['creation_date'] <= '2021-09-12' )& (df4['customer_problem_resolved'] == True )& (df4['user_team'] == 'green' )]


# Week 12
dfrtg12=df4[(df4['creation_date'] >= '2021-09-13' ) & (df4['creation_date'] <= '2021-09-19' )& (df4['customer_problem_resolved'] == True )& (df4['user_team'] == 'green' )]


# Week 13
dfrtg13=df4[(df4['creation_date'] >= '2021-09-20' ) & (df4['customer_problem_resolved'] == True )& (df4['user_team'] == 'blue' )]


#Calculate of All UnResolved ticket more than 1440 Minutes for green Team

# Week 1
dfftag1=df4[(df4['creation_date'] >= '2021-07-01' ) & (df4['creation_date'] <= '2021-07-04' )& (df4['customer_problem_resolved'] == False )& (df4['user_team'] == 'green' ) & (df4['First_time_action'] >= 1440.0 )]

# # Week 2
dfftag2=df4[(df4['creation_date'] >= '2021-07-05' ) & (df4['creation_date'] <= '2021-07-11' )& (df4['customer_problem_resolved'] == False ) & (df4['First_time_action'] >= 1440.0 )& (df4['user_team'] == 'green' )]


# Week 3
dfftag3=df4[(df4['creation_date'] >= '2021-07-12' ) & (df4['creation_date'] <= '2021-07-18' )& (df4['customer_problem_resolved'] == False ) & (df4['First_time_action'] >= 1440.0 )& (df4['user_team'] == 'green' )]


# Week 4
dfftag4=df4[(df4['creation_date'] >= '2021-07-19' ) & (df4['creation_date'] <= '2021-07-25' )& (df4['customer_problem_resolved'] == False ) & (df4['First_time_action'] >= 1440.0 )& (df4['user_team'] == 'green' )]



# # Week 5
dfftag5=df4[(df4['creation_date'] >= '2021-07-26' ) & (df4['creation_date'] <= '2021-08-01' )& (df4['customer_problem_resolved'] == False ) & (df4['First_time_action'] >= 1440.0 )& (df4['user_team'] == 'green' )]


# # Week 6
dfftag6=df4[(df4['creation_date'] >= '2021-08-02' ) & (df4['creation_date'] <= '2021-08-08' )& (df4['customer_problem_resolved'] == False ) & (df4['First_time_action'] >= 1440.0 )& (df4['user_team'] == 'green' )]


# Week 7
dfftag7=df4[(df4['creation_date'] >= '2021-08-09' ) & (df4['creation_date'] <= '2021-08-15' )& (df4['customer_problem_resolved'] == False ) & (df4['First_time_action'] >= 1440.0 )& (df4['user_team'] == 'green' )]



# Week 8
dfftag8=df4[(df4['creation_date'] >= '2021-08-16' ) & (df4['creation_date'] <= '2021-08-22' )& (df4['customer_problem_resolved'] == False ) & (df4['First_time_action'] >= 1440.0 )& (df4['user_team'] == 'green' )]


# Week 9
dfftag9=df4[(df4['creation_date'] >= '2021-08-23' ) & (df4['creation_date'] <= '2021-08-29' )& (df4['customer_problem_resolved'] == False ) & (df4['First_time_action'] >= 1440.0 )& (df4['user_team'] == 'green' )]


# Week 10
dfftag10=df4[(df4['creation_date'] >= '2021-08-30' ) & (df4['creation_date'] <= '2021-09-05' )& (df4['customer_problem_resolved'] == False ) & (df4['First_time_action'] >= 1440.0 )& (df4['user_team'] == 'green' )]


# Week 11
dfftag11=df4[(df4['creation_date'] >= '2021-09-06' ) & (df4['creation_date'] <= '2021-09-12' )& (df4['customer_problem_resolved'] == False ) & (df4['First_time_action'] >= 1440.0 )& (df4['user_team'] == 'green' )]


# Week 12
dfftag12=df4[(df4['creation_date'] >= '2021-09-13' ) & (df4['creation_date'] <= '2021-09-19' )& (df4['customer_problem_resolved'] == False ) & (df4['First_time_action'] >= 1440.0 )& (df4['user_team'] == 'green' )]


# Week 13
dfftag13=df4[(df4['creation_date'] >= '2021-09-20' ) & (df4['customer_problem_resolved'] == False )& (df4['First_time_action'] >= 1440.0 )& (df4['user_team'] == 'green' )]

# %%
#Calculate of All ticket volume for Orange

# Week 1 All ticket volume for orange team
dfcdo1=df4[(df4['creation_date'] >= '2021-07-01' ) & (df4['creation_date'] <= '2021-07-04' )& (df4['user_team'] == 'orange' )]


# # Week 2
dfcdo2=df4[(df4['creation_date'] >= '2021-07-05' ) & (df4['creation_date'] <= '2021-07-11' )& (df4['user_team'] == 'orange' )]

# Week 3
dfcdo3=df4[(df4['creation_date'] >= '2021-07-12' ) & (df4['creation_date'] <= '2021-07-18' )& (df4['user_team'] == 'orange' )]


# Week 4
dfcdo4=df4[(df4['creation_date'] >= '2021-07-19' ) & (df4['creation_date'] <= '2021-07-25' )& (df4['user_team'] == 'orange' )]


# # Week 5
dfcdo5=df4[(df4['creation_date'] >= '2021-07-26' ) & (df4['creation_date'] <= '2021-08-01' )& (df4['user_team'] == 'orange' )]

# # Week 6
dfcdo6=df4[(df4['creation_date'] >= '2021-08-02' ) & (df4['creation_date'] <= '2021-08-08' )& (df4['user_team'] == 'orange' )]


# Week 7
dfcdo7=df4[(df4['creation_date'] >= '2021-08-09' ) & (df4['creation_date'] <= '2021-08-15' )& (df4['user_team'] == 'orange' )]

# Week 8
dfcdo8=df4[(df4['creation_date'] >= '2021-08-16' ) & (df4['creation_date'] <= '2021-08-22' )& (df4['user_team'] == 'orange' )]

# Week 9
dfcdo9=df4[(df4['creation_date'] >= '2021-08-23' ) & (df4['creation_date'] <= '2021-08-29' )& (df4['user_team'] == 'orange' )]


# Week 10
dfcdo10=df4[(df4['creation_date'] >= '2021-08-30' ) & (df4['creation_date'] <= '2021-09-05' )& (df4['user_team'] == 'orange' )]

# Week 11
dfcdo11=df4[(df4['creation_date'] >= '2021-09-06' ) & (df4['creation_date'] <= '2021-09-12' )& (df4['user_team'] == 'orange' )]

# Week 12
dfcdo12=df4[(df4['creation_date'] >= '2021-09-13' ) & (df4['creation_date'] <= '2021-09-19' )& (df4['user_team'] == 'orange' )]

# Week 13
dfcdo13=df4[(df4['creation_date'] >= '2021-09-20' )& (df4['user_team'] == 'orange' ) ]




#Calculate of All Resolved ticket for orange team

# Week 1
dfrto1=df4[(df4['creation_date'] >= '2021-07-01' ) & (df4['creation_date'] <= '2021-07-04' )& (df4['customer_problem_resolved'] == True )& (df4['user_team'] == 'orange' )]

# # Week 2
dfrto2=df4[(df4['creation_date'] >= '2021-07-05' ) & (df4['creation_date'] <= '2021-07-11' )& (df4['customer_problem_resolved'] == True )& (df4['user_team'] == 'orange' )]


# Week 3
dfrto3=df4[(df4['creation_date'] >= '2021-07-12' ) & (df4['creation_date'] <= '2021-07-18' )& (df4['customer_problem_resolved'] == True )& (df4['user_team'] == 'orange' )]


# Week 4
dfrto4=df4[(df4['creation_date'] >= '2021-07-19' ) & (df4['creation_date'] <= '2021-07-25' )& (df4['customer_problem_resolved'] == True )& (df4['user_team'] == 'orange' )]



# # Week 5
dfrto5=df4[(df4['creation_date'] >= '2021-07-26' ) & (df4['creation_date'] <= '2021-08-01' )& (df4['customer_problem_resolved'] == True )& (df4['user_team'] == 'orange' )]


# # Week 6
dfrto6=df4[(df4['creation_date'] >= '2021-08-02' ) & (df4['creation_date'] <= '2021-08-08' )& (df4['customer_problem_resolved'] == True )& (df4['user_team'] == 'orange' )]


# Week 7
dfrto7=df4[(df4['creation_date'] >= '2021-08-09' ) & (df4['creation_date'] <= '2021-08-15' )& (df4['customer_problem_resolved'] == True )& (df4['user_team'] == 'orange' )]



# Week 8
dfrto8=df4[(df4['creation_date'] >= '2021-08-16' ) & (df4['creation_date'] <= '2021-08-22' )& (df4['customer_problem_resolved'] == True )& (df4['user_team'] == 'orange' )]


# Week 9
dfrto9=df4[(df4['creation_date'] >= '2021-08-23' ) & (df4['creation_date'] <= '2021-08-29' )& (df4['customer_problem_resolved'] == True )& (df4['user_team'] == 'orange' )]


# Week 10
dfrto10=df4[(df4['creation_date'] >= '2021-08-30' ) & (df4['creation_date'] <= '2021-09-05' )& (df4['customer_problem_resolved'] == True )& (df4['user_team'] == 'orange' )]


# Week 11
dfrto11=df4[(df4['creation_date'] >= '2021-09-06' ) & (df4['creation_date'] <= '2021-09-12' )& (df4['customer_problem_resolved'] == True )& (df4['user_team'] == 'orange' )]


# Week 12
dfrto12=df4[(df4['creation_date'] >= '2021-09-13' ) & (df4['creation_date'] <= '2021-09-19' )& (df4['customer_problem_resolved'] == True )& (df4['user_team'] == 'orange' )]


# Week 13
dfrto13=df4[(df4['creation_date'] >= '2021-09-20' ) & (df4['customer_problem_resolved'] == True )& (df4['user_team'] == 'orange' )]


#Calculate of All UnResolved ticket more than 1440 Minutes for orange Team

# Week 1
dfftao1=df4[(df4['creation_date'] >= '2021-07-01' ) & (df4['creation_date'] <= '2021-07-04' )& (df4['customer_problem_resolved'] == False )& (df4['user_team'] == 'orange' ) & (df4['First_time_action'] >= 1440.0 )]

# # Week 2
dfftao2=df4[(df4['creation_date'] >= '2021-07-05' ) & (df4['creation_date'] <= '2021-07-11' )& (df4['customer_problem_resolved'] == False ) & (df4['First_time_action'] >= 1440.0 )& (df4['user_team'] == 'orange' )]


# Week 3
dfftao3=df4[(df4['creation_date'] >= '2021-07-12' ) & (df4['creation_date'] <= '2021-07-18' )& (df4['customer_problem_resolved'] == False ) & (df4['First_time_action'] >= 1440.0 )& (df4['user_team'] == 'orange' )]


# Week 4
dfftao4=df4[(df4['creation_date'] >= '2021-07-19' ) & (df4['creation_date'] <= '2021-07-25' )& (df4['customer_problem_resolved'] == False ) & (df4['First_time_action'] >= 1440.0 )& (df4['user_team'] == 'orange' )]



# # Week 5
dfftao5=df4[(df4['creation_date'] >= '2021-07-26' ) & (df4['creation_date'] <= '2021-08-01' )& (df4['customer_problem_resolved'] == False ) & (df4['First_time_action'] >= 1440.0 )& (df4['user_team'] == 'orange' )]


# # Week 6
dfftao6=df4[(df4['creation_date'] >= '2021-08-02' ) & (df4['creation_date'] <= '2021-08-08' )& (df4['customer_problem_resolved'] == False ) & (df4['First_time_action'] >= 1440.0 )& (df4['user_team'] == 'orange' )]


# Week 7
dfftao7=df4[(df4['creation_date'] >= '2021-08-09' ) & (df4['creation_date'] <= '2021-08-15' )& (df4['customer_problem_resolved'] == False ) & (df4['First_time_action'] >= 1440.0 )& (df4['user_team'] == 'orange' )]



# Week 8
dfftao8=df4[(df4['creation_date'] >= '2021-08-16' ) & (df4['creation_date'] <= '2021-08-22' )& (df4['customer_problem_resolved'] == False ) & (df4['First_time_action'] >= 1440.0 )& (df4['user_team'] == 'orange' )]


# Week 9
dfftao9=df4[(df4['creation_date'] >= '2021-08-23' ) & (df4['creation_date'] <= '2021-08-29' )& (df4['customer_problem_resolved'] == False ) & (df4['First_time_action'] >= 1440.0 )& (df4['user_team'] == 'orange' )]


# Week 10
dfftao10=df4[(df4['creation_date'] >= '2021-08-30' ) & (df4['creation_date'] <= '2021-09-05' )& (df4['customer_problem_resolved'] == False ) & (df4['First_time_action'] >= 1440.0 )& (df4['user_team'] == 'orange' )]


# Week 11
dfftao11=df4[(df4['creation_date'] >= '2021-09-06' ) & (df4['creation_date'] <= '2021-09-12' )& (df4['customer_problem_resolved'] == False ) & (df4['First_time_action'] >= 1440.0 )& (df4['user_team'] == 'orange' )]


# Week 12
dfftao12=df4[(df4['creation_date'] >= '2021-09-13' ) & (df4['creation_date'] <= '2021-09-19' )& (df4['customer_problem_resolved'] == False ) & (df4['First_time_action'] >= 1440.0 )& (df4['user_team'] == 'orange' )]


# Week 13
dfftao13=df4[(df4['creation_date'] >= '2021-09-20' ) & (df4['customer_problem_resolved'] == False )& (df4['First_time_action'] >= 1440.0 )& (df4['user_team'] == 'orange' )]

# %%
@interact(Team=widgets.Dropdown(options=['orange', 'blue', 'green', 'red','Total']) )

def f(Team):
    fig, ax = plt.subplots(figsize=(10,7))
    # at below I tried to show and use different types of color palette
    colorsr = sns.light_palette(color='#b60c26',n_colors=6,reverse=False,input='hsl')
    colorsg =sns.color_palette("ch:2,r=.2,l=.6")
    colorso = sns.color_palette('Oranges')
    colorsb = sns.color_palette("ch:s=.25,rot=-.25")
    colorst = sns.cubehelix_palette(start=2.8, rot=.1)
    ax.set_title("Ticket Backlog (Unresolved tickets by "+ " " + str(Team)+ " "+ "team for more than 1440 minutes)",y=1.2, fontsize = 22 )

#     colors = ( "orange", "cyan", "brown",
#           "grey", "indigo", "beige")
# Orange Team User Satisfication
    #fig = plt.figure()
    #ax = fig.add_subplot(111)
    #fig = plt.figure(figsize =(10, 7))
# green Team User Satisfication 
    if Team=='green':
        labels = ['2021-07-04', '2021-07-11', '2021-07-18','2021-07-25','2021-08-01','2021-08-08','2021-08-15','2021-08-22','2021-08-29','2021-09-05','2021-09-12','2021-09-19','2021-09-26']
        opened_Tickets = [302, 804, 830,858, 852, 855,820, 834, 767,875, 820, 807,1273]
        Resolved = [153, 371, 381,421, 388, 396,354, 394, 347,426, 358, 369,181]
        Backlog = [1, 27, 33,60, 54, 40,47, 63, 20,40, 58, 45,91]
        width = 0.2
        x = np.arange(13)

        # plot data in grouped manner of bar type
        plt.bar(x-0.4, opened_Tickets,  color='cyan')
        plt.bar(x, Resolved,  color='orange')
        # plt.bar(x+0.2, Backlog, width, color='green')
        sns.lineplot( xg, Backlog, linewidth=2, marker='o', color='green')
        ax.set_yticks([0,100,200,300,400,500,600,700,800,900,1000,1100,1200,1300])

        ax.tick_params(axis='x',rotation=90 ) 
#         ax.set_title('Ticket Backlog ', fontsize = 18)

        plt.xticks(x, ['2021-07-04', '2021-07-11', '2021-07-18','2021-07-25','2021-08-01','2021-08-08','2021-08-15','2021-08-22','2021-08-29','2021-09-05','2021-09-12','2021-09-19','2021-09-26'])
        plt.xlabel("Weeks", fontsize = 18)
        plt.ylabel("Numbers", fontsize = 18)
        plt.legend(["Backlog(Unresolved Tickets more than 1440 Minutes)", "Opened", "Resolved"], loc= 'upper left')
        plt.show()

# Blue Team User Satisfication 
 
    if Team=='blue':
        labels = ['2021-07-04', '2021-07-11', '2021-07-18','2021-07-25','2021-08-01','2021-08-08','2021-08-15','2021-08-22','2021-08-29','2021-09-05','2021-09-12','2021-09-19','2021-09-26']
        opened_Tickets = [188, 497, 496,517, 488, 483,471, 513, 477,494, 461, 407,401]
        Resolved = [78, 212, 243,216, 211, 212,201, 235, 191,238, 208, 186,181]
        Backlog = [7, 102, 136,178, 187, 179,180, 207, 214,203, 181, 164,128]
        width = 0.2
        x = np.arange(13)

        # plot data in grouped manner of bar type
        plt.bar(x-0.4, opened_Tickets,  color='cyan')
        plt.bar(x, Resolved,  color='orange')
        # plt.bar(x+0.2, Backlog, width, color='green')
        sns.lineplot( xg, Backlog, linewidth=2, marker='o', color='green')
        ax.tick_params(axis='x',rotation=90 ) 
#         ax.set_title('Ticket Backlog ', fontsize = 18)
        ax.set_yticks([0,100,200,300,400,500,600,700,800,900,1000,1100,1200,1300])
        plt.xticks(x, ['2021-07-04', '2021-07-11', '2021-07-18','2021-07-25','2021-08-01','2021-08-08','2021-08-15','2021-08-22','2021-08-29','2021-09-05','2021-09-12','2021-09-19','2021-09-26'])
        plt.xlabel("Weeks", fontsize = 18)
        plt.ylabel("Numbers", fontsize = 18)
        plt.legend(["Backlog(Unresolved Tickets more than 1440 Minutes)", "Opened", "Resolved"], loc= 'upper left')
        plt.show()
       
        # show plot
        plt.show()
        
# Orange Team User Satisfication 
    if Team=='orange':
        labels = ['2021-07-04', '2021-07-11', '2021-07-18','2021-07-25','2021-08-01','2021-08-08','2021-08-15','2021-08-22','2021-08-29','2021-09-05','2021-09-12','2021-09-19','2021-09-26']
        opened_Tickets = [184, 463, 434,469, 455, 420,409, 369, 357,339, 273, 235,234]
        Resolved = [64, 145, 146,144, 145, 137,135, 117, 107,102, 82, 70,88]
        Backlog = [38, 178, 183,231, 231, 205,205, 176, 177,145, 115, 94,55]
        width = 0.2
        x = np.arange(13)

        # plot data in grouped manner of bar type
        plt.bar(x-0.4, opened_Tickets,  color='cyan')
        plt.bar(x, Resolved,  color='orange')
        # plt.bar(x+0.2, Backlog, width, color='green')
        sns.lineplot( xg, Backlog, linewidth=2, marker='o', color='green')
        ax.set_yticks([0,100,200,300,400,500,600,700,800,900,1000,1100,1200,1300])

        ax.tick_params(axis='x',rotation=90 ) 
#         ax.set_title('Ticket Backlog ', fontsize = 18)

        plt.xticks(x, ['2021-07-04', '2021-07-11', '2021-07-18','2021-07-25','2021-08-01','2021-08-08','2021-08-15','2021-08-22','2021-08-29','2021-09-05','2021-09-12','2021-09-19','2021-09-26'])
        plt.xlabel("Weeks", fontsize = 18)
        plt.ylabel("Numbers", fontsize = 18)
        plt.legend(["Backlog(Unresolved Tickets more than 1440 Minutes)", "Opened", "Resolved"], loc= 'upper left')
        plt.show()
        
# Red Team User Satisfication 
    if Team=='red':
        labels = ['2021-07-04', '2021-07-11', '2021-07-18','2021-07-25','2021-08-01','2021-08-08','2021-08-15','2021-08-22','2021-08-29','2021-09-05','2021-09-12','2021-09-19','2021-09-26']
        opened_Tickets = [172, 472, 472,437, 476, 453,459, 472, 450,474, 444, 479,737]
        Resolved = [86, 215, 221,202, 220, 212,202, 225, 217,235, 208, 236,343]
        Backlog = [0, 4, 42,38, 29, 7,13, 18, 41,21, 24, 16,30]
        width = 0.2
        x = np.arange(13)

        # plot data in grouped manner of bar type
        plt.bar(x-0.4, opened_Tickets,  color='cyan')
        plt.bar(x, Resolved,  color='orange')
        # plt.bar(x+0.2, Backlog, width, color='green')
        sns.lineplot( xg, Backlog, linewidth=2, marker='o', color='green')
        ax.set_yticks([0,100,200,300,400,500,600,700,800,900,1000,1100,1200,1300])

        ax.tick_params(axis='x',rotation=90 ) 
#         ax.set_title('Ticket Backlog ', fontsize = 18)

        plt.xticks(x, ['2021-07-04', '2021-07-11', '2021-07-18','2021-07-25','2021-08-01','2021-08-08','2021-08-15','2021-08-22','2021-08-29','2021-09-05','2021-09-12','2021-09-19','2021-09-26'])
        plt.xlabel("Weeks", fontsize = 18)
        plt.ylabel("Numbers", fontsize = 18)
        plt.legend(["Backlog(Unresolved Tickets more than 1440 Minutes)", "Opened", "Resolved"], loc= 'upper left')
        plt.show()
       
        # show plot
        plt.show()
# Total User Satisfication 
    if Team=='Total':
        labels = ['2021-07-04', '2021-07-11', '2021-07-18','2021-07-25','2021-08-01','2021-08-08','2021-08-15','2021-08-22','2021-08-29','2021-09-05','2021-09-12','2021-09-19','2021-09-26']
        opened_Tickets = [846, 2236, 2232,2281, 2271, 2211,2159, 2188, 2051,2182, 1998, 1928,2645]
        Resolved = [381, 943, 991,983, 964, 957,892, 971, 862,1001, 856, 861,1202]
        Backlog = [46, 311, 394,507, 501, 431,445, 464, 452,409, 378, 319,301]
        width = 0.2
        x = np.arange(13)

        # plot data in grouped manner of bar type
        plt.bar(x-0.4, opened_Tickets,  color='cyan')
        plt.bar(x, Resolved,  color='orange')
        # plt.bar(x+0.2, Backlog, width, color='green')
        sns.lineplot( xg, Backlog, linewidth=2, marker='o', color='green')
        ax.tick_params(axis='x',rotation=90 ) 
#         ax.set_title('Ticket Backlog ', fontsize = 18)

        plt.xticks(x, ['2021-07-04', '2021-07-11', '2021-07-18','2021-07-25','2021-08-01','2021-08-08','2021-08-15','2021-08-22','2021-08-29','2021-09-05','2021-09-12','2021-09-19','2021-09-26'])
        plt.xlabel("Weeks", fontsize = 18)
        plt.ylabel("Numbers", fontsize = 18)
        plt.legend(["Backlog(Unresolved Tickets more than 1440 Minutes)", "Opened", "Resolved"], loc= 'upper left')
        plt.show()
        # show plot
        plt.show()
# Out:
# interactive(children=(Dropdown(description='Team', options=('orange', 'blue', 'green', 'red', 'Total'), value=…
