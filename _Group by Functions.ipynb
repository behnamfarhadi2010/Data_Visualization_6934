# %%
import pandas as pd

# %%
df=pd.read_csv('http://bit.ly/imdbratings')

# %%
df.dtypes
# Out:
# star_rating       float64
# title              object
# content_rating     object
# genre              object
# duration            int64
# actors_list        object
# dtype: object

# %%
df
# Out:
#      star_rating                                            title  \
# 0            9.3                         The Shawshank Redemption
# 1            9.2                                    The Godfather
# 2            9.1                           The Godfather: Part II
# 3            9.0                                  The Dark Knight
# 4            8.9                                     Pulp Fiction
# ..           ...                                              ...
# 974          7.4                                          Tootsie
# 975          7.4                      Back to the Future Part III
# 976          7.4  Master and Commander: The Far Side of the World
# 977          7.4                                      Poltergeist
# 978          7.4                                      Wall Street
#
#     content_rating      genre  duration  \
# 0                R      Crime       142
# 1                R      Crime       175
# 2                R      Crime       200
# ...

# %%
df.groupby('genre').agg(['mean','median','min','max','count'])
# Out:
#           star_rating                           duration                   \
#                  mean median  min  max count        mean median  min  max
# genre
# Action       7.884559   7.80  7.4  9.0   136  126.485294  125.0   80  205
# Adventure    7.933333   7.90  7.4  8.9    75  134.840000  127.0   89  224
# Animation    7.914516   7.90  7.4  8.6    62   96.596774   94.5   75  134
# Biography    7.862338   7.80  7.4  8.9    77  131.844156  127.0   85  202
# Comedy       7.822436   7.80  7.4  8.6   156  107.602564  104.0   68  187
# Crime        7.916935   7.80  7.4  9.3   124  122.298387  118.0   67  229
# Drama        7.902518   7.90  7.4  8.9   278  126.539568  123.0   64  242
# Family       7.850000   7.85  7.8  7.9     2  107.500000  107.5  100  115
# Fantasy      7.700000   7.70  7.7  7.7     1  112.000000  112.0  112  112
# Film-Noir    8.033333   8.10  7.7  8.3     3   97.333333   93.0   88  111
# History      8.000000   8.00  8.0  8.0     1   66.000000   66.0   66   66
# ...
