# %% [markdown]
# # Assignment 07

# %% [markdown]
# # Behnam Farhadi
# ## 201994394  |  bfarhadi@mun.ca

# %% [markdown]
# ### I did this assignment individually

# %%
import pandas as pd

# %%
import numpy as np

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %%
from ipywidgets import interact, interact_manual
import ipywidgets as widgets

# %% [markdown]
# ### Question 1: (15 pts)
# ### The figure below shows the height distributions for the gold-medal winning athletes at the 2016 Olympics for several categories of sport. The points are the heights of individual athletes for the given sport.

# %%
df = pd.read_csv('olympic_athletes.csv')

# %%
df = df[(df['Year']== 2016) & (df['Medal']== 'Gold')]
df.drop_duplicates(subset='ID', keep='first')
# Out:
#             ID                             Name Sex   Age  Height  Weight  \
# 1080       608                  Ahmad Abughaush   M  20.0   178.0    68.0
# 1495       832            Nicola Virginia Adams   F  33.0   164.0    51.0
# 1849      1017           Nathan Ghar-Jun Adrian   M  27.0   198.0   100.0
# 2453      1374                    Tontowi Ahmad   M  29.0   179.0    72.0
# 2926      1634                        Taha Akgl   M  25.0   192.0   125.0
# ...        ...                              ...  ..   ...     ...     ...
# 269277  134740                     Zheng Shuyin   F  22.0   188.0    75.0
# 269312  134759  Viktoriya Yuryevna Zhilinskayte   F  27.0   188.0    80.0
# 269368  134783                    Zhong Tianshi   F  25.0   168.0    62.0
# 269511  134857                         Zhu Ting   F  21.0   198.0    78.0
# 270281  135205  Shakhobiddin Shokirovich Zoirov   M  23.0   169.0    52.0
#
#                  Team  NOC        Games  Year  Season            City  \
# ...

# %%
sss=df[(df['Sport']== 'Swimming') | (df['Sport']== 'Wrestling')|(df['Sport']== 'Fencing')| (df['Sport']== 'Athletics') | (df['Sport']== 'Shooting') | (df['Sport']== 'Cycling') | (df['Sport']== 'Rowing') | (df['Sport']== 'Gymnastics')]
sss.drop_duplicates(subset='ID', keep='first')
sss
# Out:
#             ID                           Name Sex   Age  Height  Weight  \
# 1849      1017         Nathan Ghar-Jun Adrian   M  27.0   198.0   100.0
# 1850      1017         Nathan Ghar-Jun Adrian   M  27.0   198.0   100.0
# 2926      1634                      Taha Akgl   M  25.0   192.0   125.0
# 2961      1649  Artur Kamilevich Akhmatkhuzin   M  28.0   187.0    79.0
# 3020      1682              Morolake Akinosun   F  22.0   163.0    61.0
# ...        ...                            ...  ..   ...     ...     ...
# 265216  132729  Hassan Aliazam Yazdanicharati   M  21.0   181.0    74.0
# 265365  132795      Yana Karapetovna Yegoryan   F  22.0   175.0    64.0
# 265366  132795      Yana Karapetovna Yegoryan   F  22.0   175.0    64.0
# 268857  134516                  Zhang Mengxue   F  25.0   162.0    70.0
# 269368  134783                  Zhong Tianshi   F  25.0   168.0    62.0
#
#                  Team  NOC        Games  Year  Season            City  \
# ...

# %%
fig, ax = plt.subplots(figsize=(10,8))
ax.set_title('Gold-medal Winning Heights at the 2016 Olympics')

ax = sns.violinplot(x="Sport", y="Height", data=sss, inner="quartile",scale="width")
ax = sns.swarmplot(x="Sport", y="Height", data=sss,
                   color="black")
ax.set_yticks([140,150,160,170,180,190,200,210,220])

# %%
# Out:
#             ID                             Name Sex   Age  Height  Weight  \
# 1080       608                  Ahmad Abughaush   M  20.0   178.0    68.0
# 1495       832            Nicola Virginia Adams   F  33.0   164.0    51.0
# 1849      1017           Nathan Ghar-Jun Adrian   M  27.0   198.0   100.0
# 1850      1017           Nathan Ghar-Jun Adrian   M  27.0   198.0   100.0
# 2453      1374                    Tontowi Ahmad   M  29.0   179.0    72.0
# ...        ...                              ...  ..   ...     ...     ...
# 269277  134740                     Zheng Shuyin   F  22.0   188.0    75.0
# 269312  134759  Viktoriya Yuryevna Zhilinskayte   F  27.0   188.0    80.0
# 269368  134783                    Zhong Tianshi   F  25.0   168.0    62.0
# 269511  134857                         Zhu Ting   F  21.0   198.0    78.0
# 270281  135205  Shakhobiddin Shokirovich Zoirov   M  23.0   169.0    52.0
#
#                  Team  NOC        Games  Year  Season            City  \
# ...

# %% [markdown]
# ### Question 2: (40 pts)
# ### The interactive visualization below shows the height and weight distributions for gold-medal winning athletes in the 2000 to 2016 Olympics (inclusive). The default view is a heat map of the distribution, in which the data is binned in value increments of 5 for both variables. That is, 20, 25, 30, 35, etc for Weight. (Hint: Seaborn’s heatmap is the hard way to do this. What else can bin data?)

# %%
ddd = pd.read_csv('olympic_athletes.csv')

# %%
df2=ddd.drop_duplicates(subset='ID', keep='first')
df2
# Out:
#             ID                          Name Sex   Age  Height  Weight  \
# 0            1                     A Dijiang   M  24.0   180.0    80.0
# 1            2                      A Lamusi   M  23.0   170.0    60.0
# 2            3           Gunnar Nielsen Aaby   M  24.0     NaN     NaN
# 3            4          Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 4            5      Christine Jacoba Aaftink   F  21.0   185.0    82.0
# ...        ...                           ...  ..   ...     ...     ...
# 271108  135567  Aleksandr Viktorovich Zyuzin   M  24.0   183.0    72.0
# 271110  135568        Olga Igorevna Zyuzkova   F  33.0   171.0    69.0
# 271111  135569                    Andrzej ya   M  29.0   179.0    89.0
# 271112  135570                      Piotr ya   M  27.0   176.0    59.0
# 271114  135571            Tomasz Ireneusz ya   M  30.0   185.0    96.0
#
#                   Team  NOC        Games  Year  Season            City  \
# ...

# %%
df3 = df2[(df2['Year']==2000) | (df2['Year']==2004)| (df2['Year']==2008)| (df2['Year']==2012)| (df2['Year']==2016)]
df3.sort_values(by='Year')
# Out:
#             ID                         Name Sex   Age  Height  Weight  \
# 164791   82757                Margrete Mrch   F  23.0   176.0    67.0
# 116034   58768             Abdel Hani Kenzi   M  26.0   181.0    75.0
# 213108  107008             Conny Schmalfuss   F  24.0   163.0    58.0
# 116059   58781       Abraham Kepsin Kalpumu   M  20.0   169.0    70.0
# 47272    24366              Michael Curcija   M  23.0   182.0    78.0
# ...        ...                          ...  ..   ...     ...     ...
# 217586  109289             Kathleen Sharkey   F  26.0   163.0    58.0
# 107894   54552                Jeong Ji-Geun   M  26.0   177.0    79.0
# 217598  109294  Nikolay Vasilyevich Sharlap   M  22.0   198.0   103.0
# 108016   54609            Visiline Jepkesho   F  26.0   160.0    43.0
# 271110  135568       Olga Igorevna Zyuzkova   F  33.0   171.0    69.0
#
#                  Team  NOC        Games  Year  Season            City  \
# ...

# %%
#Swimming
# dfswim = df2[(df2['Medal']== 'Gold') & (df['Sport']== 'Swimming')]
# dfswim.drop_duplicates(subset ="ID", keep='first')

# Athletics 
# dfathl = df2[(df2['Year']>1999) & (df2['Year']<2017) &(df2['Medal']== 'Gold') & (df['Sport']== 'Athletics')]
# dfathl.drop_duplicates(subset ="ID", keep='first')
# dfathl
#Wrestling
# dfwres = df2[(df2['Year']>1999) & (df2['Year']<2017) &(df2['Medal']== 'Gold') & (df['Sport']== 'Wrestling')]
# dfwres.drop_duplicates(subset ="ID", keep='first')


# #Fencing
# dffenc = df2[(df2['Year']>1999) & (df2['Year']<2017) &(df2['Medal']== 'Gold') & (df['Sport']== 'Fencing')]
# dffenc.drop_duplicates(subset ="ID", keep='first')

# #Shooting
# dfshoot = df2[(df2['Year']>1999) & (df2['Year']<2017) &(df2['Medal']== 'Gold') & (df['Sport']== 'Shooting')]
# dfshoot.drop_duplicates(subset ="ID", keep='first')

# #Cycling
# dfcycl = df2[(df2['Year']>1999) & (df2['Year']<2017) &(df2['Medal']== 'Gold') & (df['Sport']== 'Cycling')]
# dfcycl.drop_duplicates(subset ="ID", keep='first')

# #Rowing
# dfrowi = df2[(df2['Year']>1999) & (df2['Year']<2017) &(df2['Medal']== 'Gold') & (df['Sport']== 'Rowing')]
# dfrowi.drop_duplicates(subset ="ID", keep='first')

# #Gymnastics
# dfgymn = df2[(df2['Year']>1999) & (df2['Year']<2017) &(df2['Medal']== 'Gold') & (df['Sport']== 'Gymnastics')]
# dfgymn.drop_duplicates(subset ="ID", keep='first')
# Out:
# <ipython-input-383-e85bfeea6634>:10: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   dfwres = df2[(df2['Year']>1999) & (df2['Year']<2017) &(df2['Medal']== 'Gold') & (df['Sport']== 'Wrestling')]
# <ipython-input-383-e85bfeea6634>:15: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   dffenc = df2[(df2['Year']>1999) & (df2['Year']<2017) &(df2['Medal']== 'Gold') & (df['Sport']== 'Fencing')]
# <ipython-input-383-e85bfeea6634>:19: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   dfshoot = df2[(df2['Year']>1999) & (df2['Year']<2017) &(df2['Medal']== 'Gold') & (df['Sport']== 'Shooting')]
# <ipython-input-383-e85bfeea6634>:23: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   dfcycl = df2[(df2['Year']>1999) & (df2['Year']<2017) &(df2['Medal']== 'Gold') & (df['Sport']== 'Cycling')]
# ...

# %%
@interact(Sport=widgets.Dropdown(options=['Swimming','Wrestling','Fencing','Athletics','Shooting','Cycling','Rowing','Combined','Gymnastics']), Kde=False ,display_data=False )

def f(Sport, Kde ,display_data):
    
    fig, ax = plt.subplots(figsize=(10,8))
    plt.xlabel('Weight')
    plt.ylabel('Height')

# Swimming 
    if Sport=='Swimming':
        
        dfswim = df3[(df3['Medal']== 'Gold') & (df3['Sport']== 'Swimming')]
        dfswim.drop_duplicates(subset ="ID", keep='first')
        x_bins = np.linspace(20, 140, 25)
        y_bins = np.linspace(130, 220, 20)
        plt.hist2d(dfswim['Weight'], dfswim['Height'], bins =[x_bins, y_bins], cmap='Blues', cmin=1)
     
    
        if(Kde==True):
            ax3 = sns.kdeplot(data=dfswim,x="Weight", y="Height", shade=True, thresh=0.06 , ax=ax)

            ax.set_xticks([20,40,60,80,100,120,140])
    
            ax.set_yticks([130,140,150,160,170,180,190,200,210,220])

        
        if(display_data==True):
                        
            ax = sns.scatterplot(x='Weight', y='Height',data=dfswim, hue=dfswim['Sex'],ax=ax)


# Athletics 
    if Sport=='Athletics':
        
        dfathl = df3[(df3['Medal']== 'Gold') & (df3['Sport']== 'Athletics')]
        dfathl.drop_duplicates(subset ="ID", keep='first')        
        x_bins = np.linspace(20, 140, 25)
        y_bins = np.linspace(130, 220, 20)
        plt.hist2d(dfathl['Weight'], dfathl['Height'], bins =[x_bins, y_bins], cmap='Blues', cmin=1)

        
        if(Kde==True):
            ax = sns.kdeplot(data=dfathl,x="Weight", y="Height", shade=True,thresh=0.05 , ax=ax)

            ax.set_xticks([20,40,60,80,100,120,140])
    
            ax.set_yticks([130,140,150,160,170,180,190,200,210,220])   
            
        if(display_data==True):
                        
            ax = sns.scatterplot(x='Weight', y='Height',data=dfathl, hue=dfathl['Sex'],ax=ax)  
            
# Wrestling 
    if Sport=='Wrestling':
        dfwres = df3[(df3['Medal']== 'Gold') & (df3['Sport']== 'Wrestling')]
        dfwres.drop_duplicates(subset ="ID", keep='first')        
        x_bins = np.linspace(20, 140, 25)
        y_bins = np.linspace(130, 220, 20)
        plt.hist2d(dfwres['Weight'], dfwres['Height'], bins =[x_bins, y_bins], cmap='Blues', cmin=1)

        
        if(Kde==True):
            ax = sns.kdeplot(data=dfwres,x="Weight", y="Height", shade=True, thresh=0.05 , ax=ax)

            ax.set_xticks([20,40,60,80,100,120,140])
    
            ax.set_yticks([130,140,150,160,170,180,190,200,210,220])   
            
        if(display_data==True):
                        
            ax = sns.scatterplot(x='Weight', y='Height',data=dfwres, hue=dfwres['Sex'],ax=ax) 
        
#dffenc

    if Sport=='Fencing':
        dffenc = df3[(df3['Medal']== 'Gold') & (df3['Sport']== 'Fencing')]
        dffenc.drop_duplicates(subset ="ID", keep='first')         
        x_bins = np.linspace(20, 140, 25)
        y_bins = np.linspace(130, 220, 20)
        plt.hist2d(dffenc['Weight'], dffenc['Height'], bins =[x_bins, y_bins], cmap='Blues', cmin=1)

        
        if(Kde==True):
            ax = sns.kdeplot(data=dffenc,x="Weight", y="Height", shade=True, thresh=0.05 , ax=ax)

            ax.set_xticks([20,40,60,80,100,120,140])
    
            ax.set_yticks([130,140,150,160,170,180,190,200,210,220])   
            
        if(display_data==True):
                        
            ax = sns.scatterplot(x='Weight', y='Height',data=dffenc, hue=dffenc['Sex'],ax=ax) 
            

#dfshoot
    if Sport=='Shooting':
        dfshoot = df3[(df3['Medal']== 'Gold') & (df3['Sport']== 'Shooting')]
        dfshoot.drop_duplicates(subset ="ID", keep='first')        
        x_bins = np.linspace(20, 140, 25)
        y_bins = np.linspace(130, 220, 20)
        plt.hist2d(dfshoot['Weight'], dfshoot['Height'], bins =[x_bins, y_bins], cmap='Blues', cmin=0)

        
        if(Kde==True):
            ax = sns.kdeplot(data=dfshoot,x="Weight", y="Height", shade=True, thresh=0.05 , ax=ax)

            ax.set_xticks([20,40,60,80,100,120,140])
    
            ax.set_yticks([130,140,150,160,170,180,190,200,210,220])   
            
        if(display_data==True):
                        
            ax = sns.scatterplot(x='Weight', y='Height',data=dfshoot, hue=dfshoot['Sex'],ax=ax) 


#dfcycl
    if Sport=='Cycling':
        dfcycl = df3[(df3['Medal']== 'Gold') & (df3['Sport']== 'Cycling')]
        dfcycl.drop_duplicates(subset ="ID", keep='first')        
        x_bins = np.linspace(20, 140, 25)
        y_bins = np.linspace(130, 220, 20)
        plt.hist2d(dfcycl['Weight'], dfcycl['Height'], bins =[x_bins, y_bins], cmap='Blues', cmin=0)

        
        if(Kde==True):
            ax = sns.kdeplot(data=dfcycl,x="Weight", y="Height", shade=True, thresh=0.05 , ax=ax)

            ax.set_xticks([20,40,60,80,100,120,140])
    
            ax.set_yticks([130,140,150,160,170,180,190,200,210,220])   
            
        if(display_data==True):
                        
            ax = sns.scatterplot(x='Weight', y='Height',data=dfcycl, hue=dfcycl['Sex'],ax=ax) 


#dfrowi
    if Sport=='Rowing':
        dfrowi = df3[(df3['Medal']== 'Gold') & (df3['Sport']== 'Rowing')]
        dfrowi.drop_duplicates(subset ="ID", keep='first')        
        x_bins = np.linspace(20, 140, 25)
        y_bins = np.linspace(130, 220, 20)
        plt.hist2d(dfrowi['Weight'], dfrowi['Height'], bins =[x_bins, y_bins], cmap='Blues', cmin=0)

        
        if(Kde==True):
            ax = sns.kdeplot(data=dfrowi,x="Weight", y="Height", shade=True, thresh=0.05 , ax=ax)

            ax.set_xticks([20,40,60,80,100,120,140])
    
            ax.set_yticks([130,140,150,160,170,180,190,200,210,220])   
            
        if(display_data==True):
                        
            ax = sns.scatterplot(x='Weight', y='Height',data=dfrowi, hue=dfrowi['Sex'],ax=ax) 

            

#dfgymn
    if Sport=='Gymnastics':
        dfgymn = df3[(df3['Medal']== 'Gold') & (df3['Sport']== 'Gymnastics')]
        dfgymn.drop_duplicates(subset ="ID", keep='first')        
        x_bins = np.linspace(20, 140, 25)
        y_bins = np.linspace(130, 220, 20)
        plt.hist2d(dfgymn['Weight'], dfgymn['Height'], bins =[x_bins, y_bins], cmap='Blues', cmin=0)

        
        if(Kde==True):
            ax = sns.kdeplot(data=dfgymn,x="Weight", y="Height", shade=True, thresh=0.05 , ax=ax)

            ax.set_xticks([20,40,60,80,100,120,140])
    
            ax.set_yticks([130,140,150,160,170,180,190,200,210,220])   
            
        if(display_data==True):
                        
            ax = sns.scatterplot(x='Weight', y='Height',data=dfgymn, hue=dfgymn['Sex'],ax=ax)
            
            
            
#dfcomb

    if Sport=='Combined':
        dfcomb = df3[(df3['Medal']== 'Gold')]
        dfcomb.drop_duplicates(subset ="ID", keep='first')        
        x_bins = np.linspace(20, 140, 25)
        y_bins = np.linspace(130, 220, 20)
        plt.hist2d(dfcomb['Weight'], dfcomb['Height'], bins =[x_bins, y_bins], cmap='Blues', cmin=0)

        
        if(Kde==True):
            ax = sns.kdeplot(data=dfcomb,x="Weight", y="Height", shade=True, thresh=0.05 , ax=ax)

            ax.set_xticks([20,40,60,80,100,120,140])
    
            ax.set_yticks([130,140,150,160,170,180,190,200,210,220])   
            
        if(display_data==True):
                        
            ax = sns.scatterplot(x='Weight', y='Height',data=dfcomb, hue=dfcomb['Sex'],ax=ax)
# Out:
# interactive(children=(Dropdown(description='Sport', options=('Swimming', 'Wrestling', 'Fencing', 'Athletics', …
